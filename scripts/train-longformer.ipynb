# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install autocorrect -qq

from autocorrect import Speller
import re
spell = Speller(lang='en',  fast=True)
# Out:
#      |████████████████████████████████| 622 kB 7.5 MB/s
#   Building wheel for autocorrect (setup.py) ... done

# %%
# !pip install tez
# Out:
# Collecting tez
#   Downloading tez-0.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tez) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->tez) (3.10.0.2)
# Installing collected packages: tez
# Successfully installed tez-0.2.0

# %%
import os
os.mkdir('root')

# %%
# !unzip "/content/drive/MyDrive/Super Resolution/feedback-prize-2021.zip" -d "root"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: root/train/AD7E8E2D63E3.txt
#   inflating: root/train/AD802CC1863E.txt
#   inflating: root/train/AD86E73E978B.txt
#   inflating: root/train/AD8BBB12682E.txt
#   inflating: root/train/AD968694871B.txt
#   inflating: root/train/AD9CEE5A6FFF.txt
#   inflating: root/train/AD9DF5656D88.txt
#   inflating: root/train/ADA2D72FCD40.txt
#   inflating: root/train/ADA5FE621125.txt
#   inflating: root/train/ADA8F6319D6C.txt
#   inflating: root/train/ADAE8A21CE9E.txt
#   inflating: root/train/ADB29D5C3C55.txt
#   inflating: root/train/ADB68BCD2874.txt
#   inflating: root/train/ADBB29D9E179.txt
#   inflating: root/train/ADC3C0B672FA.txt
#   inflating: root/train/ADC46484D3B7.txt
#   inflating: root/train/ADC9301EE918.txt
#   inflating: root/train/ADCCB5D55577.txt
#   inflating: root/train/ADCE0BCD042D.txt
#   inflating: root/train/ADD3D2BDCC6B.txt
#   inflating: root/train/ADD688C18040.txt
#   inflating: root/train/ADD7CE85B73C.txt
#   inflating: root/train/ADDA081EE98A.txt
#   inflating: root/train/ADDAA9A7EB90.txt
#   inflating: root/train/ADDAB3785A00.txt
#   inflating: root/train/ADDF7CABF5A5.txt
#   inflating: root/train/ADE6D1DFC53B.txt
#   inflating: root/train/ADEB72AF10FC.txt
#   inflating: root/train/ADEBC8D35BF9.txt
#   inflating: root/train/ADF4E2265CE0.txt
#   inflating: root/train/ADFE2CDB6FF1.txt
#   inflating: root/train/AE021F85F4D5.txt
#   inflating: root/train/AE044D6DE72C.txt
#   inflating: root/train/AE0675B526C2.txt
#   inflating: root/train/AE0BBF382263.txt
#   inflating: root/train/AE22FB7A7670.txt
#   inflating: root/train/AE291ADFAC8D.txt
#   inflating: root/train/AE359CF88362.txt
#   inflating: root/train/AE37AE3F79C7.txt
#   inflating: root/train/AE3C9DE4FA94.txt
#   inflating: root/train/AE3CD422AAF4.txt
#   inflating: root/train/AE425A221021.txt
#   inflating: root/train/AE47AB399CF4.txt
#   inflating: root/train/AE4B0365F36A.txt
#   inflating: root/train/AE4E01E44C0F.txt
#   inflating: root/train/AE56A078E096.txt
#   inflating: root/train/AE5863E389D5.txt
#   inflating: root/train/AE587E8BC0D3.txt
#   inflating: root/train/AE5B6C4FD5B7.txt
#   inflating: root/train/AE5D214AAC85.txt
#   inflating: root/train/AE6462B51991.txt
#   inflating: root/train/AE6BABB53D5E.txt
#   inflating: root/train/AE6BE874B204.txt
#   inflating: root/train/AE6DBB2AE6DB.txt
#   inflating: root/train/AE6E407DC359.txt
#   inflating: root/train/AE72D86D1568.txt
#   inflating: root/train/AE7604228277.txt
#   inflating: root/train/AE7DE878CED5.txt
#   inflating: root/train/AE82BD8A926A.txt
#   inflating: root/train/AE844BA96314.txt
#   inflating: root/train/AE84AD104718.txt
#   inflating: root/train/AE8726362326.txt
#   inflating: root/train/AE8891205D90.txt
#   inflating: root/train/AE8CA585DC1F.txt
#   inflating: root/train/AE9E8ACD0A6F.txt
#   inflating: root/train/AEA3FC7D6E3F.txt
#   inflating: root/train/AEA5258DB0D5.txt
#   inflating: root/train/AEA73706EE2E.txt
#   inflating: root/train/AEAD5B3E70D6.txt
#   inflating: root/train/AEB124976815.txt
#   inflating: root/train/AEB7346EA9A4.txt
#   inflating: root/train/AEBBFD25000D.txt
#   inflating: root/train/AEBE65962CE3.txt
#   inflating: root/train/AEC9BAA4E7B1.txt
#   inflating: root/train/AECB1177BDC1.txt
#   inflating: root/train/AED0E44B59CE.txt
#   inflating: root/train/AED200889835.txt
#   inflating: root/train/AED7996C9DBC.txt
#   inflating: root/train/AEDF718CC5A3.txt
#   inflating: root/train/AEE04FDAE297.txt
#   inflating: root/train/AEE6C379C668.txt
#   inflating: root/train/AEE8D73906FE.txt
#   inflating: root/train/AEEEFCE714A1.txt
#   inflating: root/train/AEF85C085047.txt
#   inflating: root/train/AEFDD857A5D9.txt
#   inflating: root/train/AF0203C8BFE4.txt
#   inflating: root/train/AF05AA1A49DA.txt
#   inflating: root/train/AF077034AC88.txt
#   inflating: root/train/AF0BC75F4DBC.txt
#   inflating: root/train/AF1366A47AFE.txt
#   inflating: root/train/AF1693F74897.txt
#   inflating: root/train/AF19AACD8DAF.txt
#   inflating: root/train/AF1A2BDA829F.txt
#   inflating: root/train/AF1C86BFDC2D.txt
#   inflating: root/train/AF214D4C47A5.txt
#   inflating: root/train/AF345723174D.txt
#   inflating: root/train/AF34B1CDD152.txt
#   inflating: root/train/AF3D63DA7CB4.txt
#   inflating: root/train/AF3EC5FE6404.txt
#   inflating: root/train/AF417DD4BF66.txt
#   inflating: root/train/AF41FBC320A5.txt
#   inflating: root/train/AF4796CA4BC0.txt
#   inflating: root/train/AF47A210FE44.txt
#   inflating: root/train/AF4EE3838A58.txt
#   inflating: root/train/AF517D7FA328.txt
#   inflating: root/train/AF53D0DD6926.txt
#   inflating: root/train/AF5C9DA63FB1.txt
#   inflating: root/train/AF5E5BF38512.txt
#   inflating: root/train/AF637B7047FB.txt
#   inflating: root/train/AF642CA41345.txt
#   inflating: root/train/AF651D592CBE.txt
#   inflating: root/train/AF66DEECF5A6.txt
#   inflating: root/train/AF68F7B20B1F.txt
#   inflating: root/train/AF6EA8391841.txt
#   inflating: root/train/AF744782945F.txt
#   inflating: root/train/AF80A43C5FC9.txt
#   inflating: root/train/AF80EE1F7435.txt
#   inflating: root/train/AF9079B5EF21.txt
#   inflating: root/train/AF90C62BA52D.txt
#   inflating: root/train/AF938D285908.txt
#   inflating: root/train/AF965868B4C9.txt
#   inflating: root/train/AF96A2176FB7.txt
#   inflating: root/train/AF9AAA672210.txt
#   inflating: root/train/AFA633EBCCAA.txt
#   inflating: root/train/AFAD4C8AF912.txt
#   inflating: root/train/AFB2995F886F.txt
#   inflating: root/train/AFB59A8CCD0F.txt
#   inflating: root/train/AFBEA4BA2D3C.txt
#   inflating: root/train/AFCC087987D7.txt
#   inflating: root/train/AFCE5307F69A.txt
#   inflating: root/train/AFCF10293B9A.txt
#   inflating: root/train/AFD739EDDEA9.txt
#   inflating: root/train/AFD9DAA96F07.txt
#   inflating: root/train/AFDA24702118.txt
#   inflating: root/train/AFDB9B105CD1.txt
#   inflating: root/train/AFE9B6AA1365.txt
#   inflating: root/train/AFEC37C2D43F.txt
#   inflating: root/train/AFED7787CD81.txt
#   inflating: root/train/AFEE7E7AB2EF.txt
#   inflating: root/train/AFF314E99BF2.txt
#   inflating: root/train/AFF4F4ABC213.txt
#   inflating: root/train/AFF79308B815.txt
#   inflating: root/train/AFF882607973.txt
#   inflating: root/train/AFFD150170C8.txt
#   inflating: root/train/AFFE5877D766.txt
#   inflating: root/train/B0007528CB4A.txt
#   inflating: root/train/B000D7B81799.txt
#   inflating: root/train/B0012FA44FA2.txt
#   inflating: root/train/B0070361406D.txt
#   inflating: root/train/B00B5447FE83.txt
#   inflating: root/train/B01B2F50425E.txt
#   inflating: root/train/B02A4DDA8FC7.txt
#   inflating: root/train/B02AD8EE0DF0.txt
#   inflating: root/train/B0401C647A05.txt
#   inflating: root/train/B046369E5206.txt
#   inflating: root/train/B04BEFD69D01.txt
#   inflating: root/train/B04DEC188939.txt
#   inflating: root/train/B04EBE5811B6.txt
#   inflating: root/train/B056CFFBFF3C.txt
#   inflating: root/train/B0576F7D8C8A.txt
#   inflating: root/train/B05A40461916.txt
#   inflating: root/train/B064654D4BB8.txt
#   inflating: root/train/B06F15F11C93.txt
#   inflating: root/train/B071D5619C92.txt
#   inflating: root/train/B0734086A30E.txt
#   inflating: root/train/B07E96B9767C.txt
#   inflating: root/train/B07F2237C606.txt
#   inflating: root/train/B082F1A267EE.txt
#   inflating: root/train/B083862AF3B4.txt
#   inflating: root/train/B0846915EE1A.txt
#   inflating: root/train/B08778A20E76.txt
#   inflating: root/train/B08943432C17.txt
#   inflating: root/train/B09064197CEF.txt
#   inflating: root/train/B095598DEE04.txt
#   inflating: root/train/B098FABF15D7.txt
#   inflating: root/train/B09CB4CB2D85.txt
#   inflating: root/train/B09E38E0E8EC.txt
#   inflating: root/train/B0A08E744DF1.txt
#   inflating: root/train/B0A19F407570.txt
#   inflating: root/train/B0A2264C9BD9.txt
#   inflating: root/train/B0AB337A9B59.txt
#   inflating: root/train/B0AD7021AB07.txt
#   inflating: root/train/B0B6E65301EB.txt
#   inflating: root/train/B0C3BA432D21.txt
#   inflating: root/train/B0C3BBF86B9B.txt
#   inflating: root/train/B0C685E8EA1A.txt
#   inflating: root/train/B0C6EF6A3100.txt
#   inflating: root/train/B0C7779B7276.txt
#   inflating: root/train/B0C80C0550D7.txt
#   inflating: root/train/B0CA3173B40D.txt
#   inflating: root/train/B0CCFA21F82C.txt
#   inflating: root/train/B0CE869365CB.txt
#   inflating: root/train/B0D2190F7312.txt
#   inflating: root/train/B0D5228E9FBD.txt
#   inflating: root/train/B0D9B3EA4E5A.txt
#   inflating: root/train/B0DB49483D7C.txt
#   inflating: root/train/B0E17505BCB3.txt
#   inflating: root/train/B0E2A499FC5A.txt
#   inflating: root/train/B0E46A7013DB.txt
#   inflating: root/train/B0E846E42C45.txt
#   inflating: root/train/B0E93CC3E195.txt
#   inflating: root/train/B0EA4F7B076C.txt
#   inflating: root/train/B0EB441FDE3A.txt
#   inflating: root/train/B0ED18C04F15.txt
#   inflating: root/train/B0F3FA7DE6CE.txt
#   inflating: root/train/B0F5A3880ECB.txt
#   inflating: root/train/B0F645CD20FF.txt
#   inflating: root/train/B0F93DDE518C.txt
#   inflating: root/train/B0FC895D460A.txt
#   inflating: root/train/B10961803408.txt
#   inflating: root/train/B10E3AABDC7C.txt
#   inflating: root/train/B1107C007404.txt
#   inflating: root/train/B111395C3C6E.txt
#   inflating: root/train/B11834311A67.txt
#   inflating: root/train/B119CD1A5145.txt
#   inflating: root/train/B11D35EE7B0F.txt
#   inflating: root/train/B12531DE8E75.txt
#   inflating: root/train/B127CFD81E92.txt
#   inflating: root/train/B12D568E5775.txt
#   inflating: root/train/B131205A86C4.txt
#   inflating: root/train/B133FCABD0AF.txt
#   inflating: root/train/B1366D129A19.txt
#   inflating: root/train/B13B81A12D38.txt
#   inflating: root/train/B1473F247979.txt
#   inflating: root/train/B147D42BE3AC.txt
#   inflating: root/train/B150E66D6C5B.txt
#   inflating: root/train/B150F36A25B2.txt
#   inflating: root/train/B154F5F9DADF.txt
#   inflating: root/train/B1586F3E92EE.txt
#   inflating: root/train/B1589F9F0ADB.txt
#   inflating: root/train/B15AE8E4985E.txt
#   inflating: root/train/B15AF429027A.txt
#   inflating: root/train/B15B3D1D9CB5.txt
#   inflating: root/train/B15CAAF6DF04.txt
#   inflating: root/train/B15DCC651E2D.txt
#   inflating: root/train/B15EA1EE9302.txt
#   inflating: root/train/B165E46F2D0C.txt
#   inflating: root/train/B1687066F985.txt
#   inflating: root/train/B168CD238CA1.txt
#   inflating: root/train/B16C6D2C17BE.txt
#   inflating: root/train/B1703E8A7555.txt
#   inflating: root/train/B17127A30AC0.txt
#   inflating: root/train/B17816AD0AF8.txt
#   inflating: root/train/B17A3A770A17.txt
#   inflating: root/train/B17A58769FF3.txt
#   inflating: root/train/B17BA16FC145.txt
#   inflating: root/train/B17BDAC0197F.txt
#   inflating: root/train/B181B21A4FA6.txt
#   inflating: root/train/B185CAA596E4.txt
#   inflating: root/train/B18624117239.txt
#   inflating: root/train/B18781945C73.txt
#   inflating: root/train/B18CC50F5A1A.txt
#   inflating: root/train/B18FB042DEDD.txt
#   inflating: root/train/B1931B07D749.txt
#   inflating: root/train/B193591E3477.txt
#   inflating: root/train/B19940812E58.txt
#   inflating: root/train/B19B1C98C30D.txt
#   inflating: root/train/B1A87B210C0F.txt
#   inflating: root/train/B1AF3AD74555.txt
#   inflating: root/train/B1B0D8237ED0.txt
#   inflating: root/train/B1B4B7672457.txt
#   inflating: root/train/B1BDD6AA0E1B.txt
#   inflating: root/train/B1C0DDEE474D.txt
#   inflating: root/train/B1D1773E6798.txt
#   inflating: root/train/B1D7630EE532.txt
#   inflating: root/train/B1DB05B61A1F.txt
#   inflating: root/train/B1E590527982.txt
#   inflating: root/train/B1E6DCD4F05F.txt
#   inflating: root/train/B1E87F6E9C5A.txt
#   inflating: root/train/B1EBAAE6E651.txt
#   inflating: root/train/B1EF45488EA7.txt
#   inflating: root/train/B1EFFE527751.txt
#   inflating: root/train/B1F07D72CCB4.txt
#   inflating: root/train/B1F0FEE0C6A2.txt
#   inflating: root/train/B1F6435E3589.txt
#   inflating: root/train/B1F95DB388DB.txt
#   inflating: root/train/B1FAD06077ED.txt
#   inflating: root/train/B1FBA75AD961.txt
#   inflating: root/train/B1FC2FA3AFB3.txt
#   inflating: root/train/B211B7A637A9.txt
#   inflating: root/train/B21251EB9781.txt
#   inflating: root/train/B215E1BAC336.txt
#   inflating: root/train/B216794ACCCA.txt
#   inflating: root/train/B21F63120303.txt
#   inflating: root/train/B222F9F093CB.txt
#   inflating: root/train/B2266B51FEBB.txt
#   inflating: root/train/B22F03F49B0E.txt
#   inflating: root/train/B2305853B773.txt
#   inflating: root/train/B2343ABCE020.txt
#   inflating: root/train/B237EA09433F.txt
#   inflating: root/train/B23941DFCB72.txt
#   inflating: root/train/B23BDDB4B5FA.txt
#   inflating: root/train/B240AC102237.txt
#   inflating: root/train/B2426E4674E7.txt
#   inflating: root/train/B242BB046FED.txt
#   inflating: root/train/B244C8A87C37.txt
#   inflating: root/train/B24560CD0812.txt
#   inflating: root/train/B24B60C74429.txt
#   inflating: root/train/B24EE1A93A0B.txt
#   inflating: root/train/B25D365F5C1C.txt
#   inflating: root/train/B266554D2E66.txt
#   inflating: root/train/B269D53897D9.txt
#   inflating: root/train/B26ED6F34796.txt
#   inflating: root/train/B27585EF3751.txt
#   inflating: root/train/B27C4443F88F.txt
#   inflating: root/train/B27DD0B12E19.txt
#   inflating: root/train/B286E6029ECB.txt
#   inflating: root/train/B286EEAB83F6.txt
#   inflating: root/train/B28B37BFCC03.txt
#   inflating: root/train/B28CE3CD571D.txt
#   inflating: root/train/B29198FD0748.txt
#   inflating: root/train/B295BC411B70.txt
#   inflating: root/train/B29CFA250576.txt
#   inflating: root/train/B2AE28A167B1.txt
#   inflating: root/train/B2B0FD5FBBBB.txt
#   inflating: root/train/B2C1191E4FEF.txt
#   inflating: root/train/B2C131C2B3AB.txt
#   inflating: root/train/B2C4FA163339.txt
#   inflating: root/train/B2D03F892B0D.txt
#   inflating: root/train/B2D57A646363.txt
#   inflating: root/train/B2D8F2DDDCBE.txt
#   inflating: root/train/B2DAE4CC6597.txt
#   inflating: root/train/B2DDBAAC084C.txt
#   inflating: root/train/B2E85A9A8F9C.txt
#   inflating: root/train/B2EA7472707E.txt
#   inflating: root/train/B2EE7ADD5BFA.txt
#   inflating: root/train/B2F4B9604E5F.txt
#   inflating: root/train/B2F51A10762D.txt
#   inflating: root/train/B2F69B97BC2A.txt
#   inflating: root/train/B2F7B08EA688.txt
#   inflating: root/train/B2F8D6D0CB9D.txt
#   inflating: root/train/B2FF6A761EC9.txt
#   inflating: root/train/B30188D7A074.txt
#   inflating: root/train/B3091F020981.txt
#   inflating: root/train/B30A57DB8F04.txt
#   inflating: root/train/B30E789C19ED.txt
#   inflating: root/train/B30F2CD326C3.txt
#   inflating: root/train/B30F7524C444.txt
#   inflating: root/train/B312F104B015.txt
#   inflating: root/train/B3165EE32FDC.txt
#   inflating: root/train/B3176BB24009.txt
#   inflating: root/train/B31A327A4698.txt
#   inflating: root/train/B31E67E692E4.txt
#   inflating: root/train/B31F203DB1A8.txt
#   inflating: root/train/B321A3B98AB5.txt
#   inflating: root/train/B3249050C067.txt
#   inflating: root/train/B32F41984B27.txt
#   inflating: root/train/B330C76B790E.txt
#   inflating: root/train/B332BF8E25FF.txt
#   inflating: root/train/B333D8C9BAE4.txt
#   inflating: root/train/B33757C833AA.txt
#   inflating: root/train/B3388EF1E80C.txt
#   inflating: root/train/B33AAEEF92E5.txt
#   inflating: root/train/B33BA4AD552E.txt
#   inflating: root/train/B33BCDF39B04.txt
#   inflating: root/train/B34118DCC728.txt
#   inflating: root/train/B343F5E7C7BA.txt
#   inflating: root/train/B3493FBE6476.txt
#   inflating: root/train/B34CA80A1C23.txt
#   inflating: root/train/B3526897360F.txt
#   inflating: root/train/B3541C7B8380.txt
#   inflating: root/train/B356D7FBA362.txt
#   inflating: root/train/B35B894BDDEF.txt
#   inflating: root/train/B35CDBFBD6D1.txt
#   inflating: root/train/B365484CCA8F.txt
#   inflating: root/train/B3665AE0A869.txt
#   inflating: root/train/B36BDB586EEF.txt
#   inflating: root/train/B36C72D38CBC.txt
#   inflating: root/train/B36CF0CB30E5.txt
#   inflating: root/train/B3712DCA6C26.txt
#   inflating: root/train/B371C925A2B2.txt
#   inflating: root/train/B37483011EC6.txt
#   inflating: root/train/B374D93D2A76.txt
#   inflating: root/train/B37E64E1BE1E.txt
#   inflating: root/train/B3813CAD3B8D.txt
#   inflating: root/train/B3842469B183.txt
#   inflating: root/train/B38881EFDCA2.txt
#   inflating: root/train/B38B82E3F538.txt
#   inflating: root/train/B38CEB26C2AB.txt
#   inflating: root/train/B38D6D958DB1.txt
#   inflating: root/train/B38DBE0AD1B2.txt
#   inflating: root/train/B38E6E6D3731.txt
#   inflating: root/train/B392C89CA90E.txt
#   inflating: root/train/B3948CC26153.txt
#   inflating: root/train/B396296EF19F.txt
#   inflating: root/train/B3963F9DB39C.txt
#   inflating: root/train/B39E22A349BD.txt
#   inflating: root/train/B39F2225875C.txt
#   inflating: root/train/B39FCEF07F51.txt
#   inflating: root/train/B3A2B0817A9F.txt
#   inflating: root/train/B3A666840EE1.txt
#   inflating: root/train/B3A830730FB7.txt
#   inflating: root/train/B3AB4E6C5678.txt
#   inflating: root/train/B3B624F3F792.txt
#   inflating: root/train/B3BA6F87F618.txt
#   inflating: root/train/B3BBBAE51416.txt
#   inflating: root/train/B3C2E6274311.txt
#   inflating: root/train/B3C35FE7E3B3.txt
#   inflating: root/train/B3C82409B8C2.txt
#   inflating: root/train/B3C8CE820C5D.txt
#   inflating: root/train/B3CB635C4341.txt
#   inflating: root/train/B3CF4188DC2F.txt
#   inflating: root/train/B3D847341452.txt
#   inflating: root/train/B3D92EA18E0F.txt
#   inflating: root/train/B3DCC9D9797B.txt
#   inflating: root/train/B3DE1C2B5D67.txt
#   inflating: root/train/B3E4B633261B.txt
#   inflating: root/train/B3F446BF0A11.txt
#   inflating: root/train/B402430B0616.txt
#   inflating: root/train/B4025ED10B7E.txt
#   inflating: root/train/B404C9B45527.txt
#   inflating: root/train/B40DD5822E7E.txt
#   inflating: root/train/B40F33AD93D5.txt
#   inflating: root/train/B4143F38D439.txt
#   inflating: root/train/B414B1D87DD6.txt
#   inflating: root/train/B4171FDA94FA.txt
#   inflating: root/train/B41900D2BB5B.txt
#   inflating: root/train/B41D279BCB0B.txt
#   inflating: root/train/B42C80CF7718.txt
#   inflating: root/train/B430B6820321.txt
#   inflating: root/train/B437EB073109.txt
#   inflating: root/train/B438121FAF21.txt
#   inflating: root/train/B43A357A9F90.txt
#   inflating: root/train/B43C1055C489.txt
#   inflating: root/train/B43F583ECE54.txt
#   inflating: root/train/B448777FA565.txt
#   inflating: root/train/B44F4F2E6178.txt
#   inflating: root/train/B4528CE5BB12.txt
#   inflating: root/train/B455EB15E59C.txt
#   inflating: root/train/B45B48157399.txt
#   inflating: root/train/B460B20EE678.txt
#   inflating: root/train/B460DDD6C6CA.txt
#   inflating: root/train/B462DD2E5524.txt
#   inflating: root/train/B4674B3DF341.txt
#   inflating: root/train/B46913FEF3E9.txt
#   inflating: root/train/B46A2BA39974.txt
#   inflating: root/train/B471DC1A142D.txt
#   inflating: root/train/B471DE76B9ED.txt
#   inflating: root/train/B47AF7F1BAAD.txt
#   inflating: root/train/B48302EAFB68.txt
#   inflating: root/train/B48644515CD6.txt
#   inflating: root/train/B48D82A4EC73.txt
#   inflating: root/train/B48FC4918B8F.txt
#   inflating: root/train/B496C551E6D8.txt
#   inflating: root/train/B4994C771190.txt
#   inflating: root/train/B49B10AE4548.txt
#   inflating: root/train/B49ED6AC9AF3.txt
#   inflating: root/train/B4A29F141270.txt
#   inflating: root/train/B4AC3F641AFF.txt
#   inflating: root/train/B4B605F897BC.txt
#   inflating: root/train/B4B8BEB77C2E.txt
#   inflating: root/train/B4BC1C61F5DA.txt
#   inflating: root/train/B4BD4DD677AD.txt
#   inflating: root/train/B4C37CA739D1.txt
#   inflating: root/train/B4C4BABFB290.txt
#   inflating: root/train/B4C5B9F3FB4E.txt
#   inflating: root/train/B4CB3063482A.txt
#   inflating: root/train/B4D70523689C.txt
#   inflating: root/train/B4D91520B347.txt
#   inflating: root/train/B4DEA93DAA5B.txt
#   inflating: root/train/B4E8CF251A0D.txt
#   inflating: root/train/B4F3E5D8D7D2.txt
#   inflating: root/train/B4F4CD4F2A11.txt
#   inflating: root/train/B4F6234EE053.txt
#   inflating: root/train/B4F68B3BBAA4.txt
#   inflating: root/train/B4F7C5D9CA8D.txt
#   inflating: root/train/B4FBC20225BC.txt
#   inflating: root/train/B4FCF8DD1F69.txt
#   inflating: root/train/B4FD96336393.txt
#   inflating: root/train/B500090869F9.txt
#   inflating: root/train/B50051C3D65F.txt
#   inflating: root/train/B5015A51C0A5.txt
#   inflating: root/train/B50239696FDC.txt
#   inflating: root/train/B5083253724F.txt
#   inflating: root/train/B50B1FFB4697.txt
#   inflating: root/train/B5113469D13C.txt
#   inflating: root/train/B51E027B51AF.txt
#   inflating: root/train/B51FB7EF1F85.txt
#   inflating: root/train/B5235448CF1F.txt
#   inflating: root/train/B526BA896931.txt
#   inflating: root/train/B527F1CEBDA4.txt
#   inflating: root/train/B52827FC9CCD.txt
#   inflating: root/train/B5330C56B5B8.txt
#   inflating: root/train/B53910E9E75D.txt
#   inflating: root/train/B53ED19CD783.txt
#   inflating: root/train/B541C87764FC.txt
#   inflating: root/train/B54887373043.txt
#   inflating: root/train/B54C2AEBD0A2.txt
#   inflating: root/train/B5515A9C682B.txt
#   inflating: root/train/B55DD4BF3B1B.txt
#   inflating: root/train/B55E154D6BE3.txt
#   inflating: root/train/B55FF7648652.txt
#   inflating: root/train/B562D63C7817.txt
#   inflating: root/train/B565CBCD43E6.txt
#   inflating: root/train/B567AD10DA07.txt
#   inflating: root/train/B568E9BC99FD.txt
#   inflating: root/train/B56ABAADC95A.txt
#   inflating: root/train/B57C860BE032.txt
#   inflating: root/train/B5838ACCDBA5.txt
#   inflating: root/train/B5868ECDF875.txt
#   inflating: root/train/B58C0C13ED8B.txt
#   inflating: root/train/B590CD509578.txt
#   inflating: root/train/B59382C26036.txt
#   inflating: root/train/B59B6731525B.txt
#   inflating: root/train/B5A5CFDCE29E.txt
#   inflating: root/train/B5A7C13D13B8.txt
#   inflating: root/train/B5AFFE1A4431.txt
#   inflating: root/train/B5B008D3B5FD.txt
#   inflating: root/train/B5B5BB3CB4EC.txt
#   inflating: root/train/B5B6FDA75B5E.txt
#   inflating: root/train/B5BB734A713B.txt
#   inflating: root/train/B5BE21756CF7.txt
#   inflating: root/train/B5BFAD94E4E7.txt
#   inflating: root/train/B5C1F852C9F8.txt
#   inflating: root/train/B5C3DC4A876E.txt
#   inflating: root/train/B5C606F0A883.txt
#   inflating: root/train/B5CA9C10711C.txt
#   inflating: root/train/B5CAA2329C07.txt
#   inflating: root/train/B5CBE846C3F7.txt
#   inflating: root/train/B5CC94F03E06.txt
#   inflating: root/train/B5CE3C6DAAD9.txt
#   inflating: root/train/B5CFB2339EF5.txt
#   inflating: root/train/B5D9F34D2CAC.txt
#   inflating: root/train/B5DB0D021C61.txt
#   inflating: root/train/B5DBDEBA4B23.txt
#   inflating: root/train/B5DE2FAE1DB5.txt
#   inflating: root/train/B5E26D74877D.txt
#   inflating: root/train/B5F53F784EE2.txt
#   inflating: root/train/B5F54C170E16.txt
#   inflating: root/train/B5FF33681C22.txt
#   inflating: root/train/B601B21F968F.txt
#   inflating: root/train/B608721A4DF0.txt
#   inflating: root/train/B60965F6B17C.txt
#   inflating: root/train/B60A2DC4B93C.txt
#   inflating: root/train/B60AC5648815.txt
#   inflating: root/train/B60B36C3BA2D.txt
#   inflating: root/train/B60BD5B9D118.txt
#   inflating: root/train/B60E0310BEBE.txt
#   inflating: root/train/B6113C09A9DE.txt
#   inflating: root/train/B617FC07CCB6.txt
#   inflating: root/train/B61FF40EE999.txt
#   inflating: root/train/B625D4DD844E.txt
#   inflating: root/train/B6261FF12B56.txt
#   inflating: root/train/B63358D526BC.txt
#   inflating: root/train/B63EAF46C812.txt
#   inflating: root/train/B6428F6EB5F3.txt
#   inflating: root/train/B64326635AB6.txt
#   inflating: root/train/B6467F2220B6.txt
#   inflating: root/train/B64898B85B89.txt
#   inflating: root/train/B64B9CDA1E54.txt
#   inflating: root/train/B64E5519018D.txt
#   inflating: root/train/B651AEF954C3.txt
#   inflating: root/train/B65361F90B72.txt
#   inflating: root/train/B654298A5760.txt
#   inflating: root/train/B65873355FA8.txt
#   inflating: root/train/B659CCF9A5C5.txt
#   inflating: root/train/B65ABA471638.txt
#   inflating: root/train/B663B3EDB8F7.txt
#   inflating: root/train/B6666AE07D46.txt
#   inflating: root/train/B6695545FC89.txt
#   inflating: root/train/B6754C50B4F0.txt
#   inflating: root/train/B67C452749B8.txt
#   inflating: root/train/B67D550009E8.txt
#   inflating: root/train/B67DFD07510C.txt
#   inflating: root/train/B6813C0A2302.txt
#   inflating: root/train/B689C28463CB.txt
#   inflating: root/train/B68A2726F120.txt
#   inflating: root/train/B68ED8EDBA5D.txt
#   inflating: root/train/B6956F44BAEB.txt
#   inflating: root/train/B69D877AD701.txt
#   inflating: root/train/B69DE280DD9D.txt
#   inflating: root/train/B6A7E0AA3574.txt
#   inflating: root/train/B6AB1B1F7364.txt
#   inflating: root/train/B6ADC9221B47.txt
#   inflating: root/train/B6B1ADD3EC37.txt
#   inflating: root/train/B6B28560FA92.txt
#   inflating: root/train/B6B2D2FC8F3D.txt
#   inflating: root/train/B6B384CA5F18.txt
#   inflating: root/train/B6B7196E454E.txt
#   inflating: root/train/B6B83F631471.txt
#   inflating: root/train/B6C009160238.txt
#   inflating: root/train/B6C0D82C6F85.txt
#   inflating: root/train/B6CF725EDB08.txt
#   inflating: root/train/B6D4400A3B06.txt
#   inflating: root/train/B6D6666FEF89.txt
#   inflating: root/train/B6D6889E36A1.txt
#   inflating: root/train/B6D776FC5087.txt
#   inflating: root/train/B6D833F8240B.txt
#   inflating: root/train/B6E5218738F0.txt
#   inflating: root/train/B6E9E12159E3.txt
#   inflating: root/train/B6F03D0CEABE.txt
#   inflating: root/train/B6F12A1662D4.txt
#   inflating: root/train/B6F445EE304C.txt
#   inflating: root/train/B6FA14E88F99.txt
#   inflating: root/train/B700273E7D4B.txt
#   inflating: root/train/B70499950AB4.txt
#   inflating: root/train/B7075CD10BCC.txt
#   inflating: root/train/B709F976724E.txt
#   inflating: root/train/B71521CCA4F4.txt
#   inflating: root/train/B717EF32EE00.txt
#   inflating: root/train/B724D11E09C5.txt
#   inflating: root/train/B727B720430B.txt
#   inflating: root/train/B72812E8C21F.txt
#   inflating: root/train/B72814616287.txt
#   inflating: root/train/B72D0B4875B4.txt
#   inflating: root/train/B731B6D15B45.txt
#   inflating: root/train/B736B35EC849.txt
#   inflating: root/train/B73FE4F761D2.txt
#   inflating: root/train/B74091BD48A1.txt
#   inflating: root/train/B7468C4DD17C.txt
#   inflating: root/train/B74852381DC0.txt
#   inflating: root/train/B74D2F25FD01.txt
#   inflating: root/train/B74EC94193F8.txt
#   inflating: root/train/B75E90DC14B3.txt
#   inflating: root/train/B75F6B21DD30.txt
#   inflating: root/train/B760F98AB4A8.txt
#   inflating: root/train/B7625BE2F0E5.txt
#   inflating: root/train/B76280E881AE.txt
#   inflating: root/train/B7685AA86F85.txt
#   inflating: root/train/B77CB9C82BCB.txt
#   inflating: root/train/B7819FA33B21.txt
#   inflating: root/train/B78889CD7103.txt
#   inflating: root/train/B78A191477C9.txt
#   inflating: root/train/B78A347F570E.txt
#   inflating: root/train/B78D97197A81.txt
#   inflating: root/train/B78FDCCC587F.txt
#   inflating: root/train/B7945FDAB292.txt
#   inflating: root/train/B79635E19C40.txt
#   inflating: root/train/B796909E583C.txt
#   inflating: root/train/B79712C5818C.txt
#   inflating: root/train/B799DAFE0950.txt
#   inflating: root/train/B79ABAFC71D1.txt
#   inflating: root/train/B79D1BD832C1.txt
#   inflating: root/train/B79DB58FFBA0.txt
#   inflating: root/train/B79E9AC3F3A0.txt
#   inflating: root/train/B79F66D2BECA.txt
#   inflating: root/train/B7A015945756.txt
#   inflating: root/train/B7A0347C68C3.txt
#   inflating: root/train/B7ACED7ED339.txt
#   inflating: root/train/B7AE34990F95.txt
#   inflating: root/train/B7B158E7E87B.txt
#   inflating: root/train/B7B88E6FF395.txt
#   inflating: root/train/B7BB7AA2B5BC.txt
#   inflating: root/train/B7BC85276656.txt
#   inflating: root/train/B7BD2B00214C.txt
#   inflating: root/train/B7BD520BE938.txt
#   inflating: root/train/B7BE5DC0C28C.txt
#   inflating: root/train/B7C17E1993BA.txt
#   inflating: root/train/B7C1ABD185A4.txt
#   inflating: root/train/B7C3128E0973.txt
#   inflating: root/train/B7D35EEA97FF.txt
#   inflating: root/train/B7D6C2BADE28.txt
#   inflating: root/train/B7E1A842F675.txt
#   inflating: root/train/B7E3F460802A.txt
#   inflating: root/train/B7E936A82959.txt
#   inflating: root/train/B7E9862AA0E0.txt
#   inflating: root/train/B7E98C5C578F.txt
#   inflating: root/train/B7EDCEA9137B.txt
#   inflating: root/train/B7EF8F40B761.txt
#   inflating: root/train/B7F586D0260C.txt
#   inflating: root/train/B8066E8A285A.txt
#   inflating: root/train/B80BB8B7FC15.txt
#   inflating: root/train/B80E6D8F9AC4.txt
#   inflating: root/train/B8164EA79177.txt
#   inflating: root/train/B81988A56B6A.txt
#   inflating: root/train/B81A83BDADA7.txt
#   inflating: root/train/B81F04CAAC43.txt
#   inflating: root/train/B81F8D4BF791.txt
#   inflating: root/train/B81FEF759FD2.txt
#   inflating: root/train/B8206613E7D9.txt
#   inflating: root/train/B82D39FFC692.txt
#   inflating: root/train/B8321F8B104D.txt
#   inflating: root/train/B83D6D54324F.txt
#   inflating: root/train/B84458707731.txt
#   inflating: root/train/B8476CE22AF9.txt
#   inflating: root/train/B84A7F39D6A1.txt
#   inflating: root/train/B84EF55EE7F0.txt
#   inflating: root/train/B859B86268ED.txt
#   inflating: root/train/B864F3DC71FC.txt
#   inflating: root/train/B8665C05D2B4.txt
#   inflating: root/train/B866BB794434.txt
#   inflating: root/train/B867F487B9F3.txt
#   inflating: root/train/B86BB171770C.txt
#   inflating: root/train/B86C55038B18.txt
#   inflating: root/train/B86D09F6A43A.txt
#   inflating: root/train/B871AAD79344.txt
#   inflating: root/train/B8748AECBD72.txt
#   inflating: root/train/B8757E80EB9D.txt
#   inflating: root/train/B87765D67542.txt
#   inflating: root/train/B87D3E1BB6A8.txt
#   inflating: root/train/B87D59512568.txt
#   inflating: root/train/B87E8822B2D2.txt
#   inflating: root/train/B88301B4E6D7.txt
#   inflating: root/train/B883B02C3638.txt
#   inflating: root/train/B884018E887C.txt
#   inflating: root/train/B88543B512DE.txt
#   inflating: root/train/B8871B9AAEBC.txt
#   inflating: root/train/B88A1ED73119.txt
#   inflating: root/train/B895B5625DCF.txt
#   inflating: root/train/B89BB1FC1E1F.txt
#   inflating: root/train/B89DED9517AE.txt
#   inflating: root/train/B89F37555A14.txt
#   inflating: root/train/B89FAB59B1B3.txt
#   inflating: root/train/B8A2B64B089F.txt
#   inflating: root/train/B8A754A0B9DD.txt
#   inflating: root/train/B8AB4C6E1F5A.txt
#   inflating: root/train/B8B5B46DA523.txt
#   inflating: root/train/B8B64FD4EF6B.txt
#   inflating: root/train/B8BC8A959CF0.txt
#   inflating: root/train/B8BE5466E96B.txt
#   inflating: root/train/B8CA9E3E3100.txt
#   inflating: root/train/B8CAE254E601.txt
#   inflating: root/train/B8CCEB5C0CE6.txt
#   inflating: root/train/B8D49BD571C2.txt
#   inflating: root/train/B8D9250543E0.txt
#   inflating: root/train/B8DB908ED424.txt
#   inflating: root/train/B8DB95775FBA.txt
#   inflating: root/train/B8E0146FEFD9.txt
#   inflating: root/train/B8E816DA2049.txt
#   inflating: root/train/B8EA14D3E542.txt
#   inflating: root/train/B8EAF80A1409.txt
#   inflating: root/train/B8EB9AC4606F.txt
#   inflating: root/train/B8F20E4A2425.txt
#   inflating: root/train/B8FAA6380D53.txt
#   inflating: root/train/B8FB806ECDA3.txt
#   inflating: root/train/B8FCB3C2CB97.txt
#   inflating: root/train/B8FEB34C1378.txt
#   inflating: root/train/B8FF5353E626.txt
#   inflating: root/train/B900AB9B5FEA.txt
#   inflating: root/train/B9015F213291.txt
#   inflating: root/train/B902933C58CB.txt
#   inflating: root/train/B90A219BB957.txt
#   inflating: root/train/B90C3ED7033F.txt
#   inflating: root/train/B90C8C40C0A0.txt
#   inflating: root/train/B90F11A85F0A.txt
#   inflating: root/train/B91A56C03A1F.txt
#   inflating: root/train/B91B697EB28E.txt
#   inflating: root/train/B91C344934D2.txt
#   inflating: root/train/B92A891555CA.txt
#   inflating: root/train/B92B378E1264.txt
#   inflating: root/train/B932887DC40A.txt
#   inflating: root/train/B9347CDF2461.txt
#   inflating: root/train/B934F3106FCB.txt
#   inflating: root/train/B93581E854BD.txt
#   inflating: root/train/B936994E140D.txt
#   inflating: root/train/B939C9FDDAB0.txt
#   inflating: root/train/B93B3ABAA7F5.txt
#   inflating: root/train/B94059412B2C.txt
#   inflating: root/train/B947F9493FAF.txt
#   inflating: root/train/B948C72229B3.txt
#   inflating: root/train/B94E4F75BA1D.txt
#   inflating: root/train/B95153DCC67E.txt
#   inflating: root/train/B95270A9AB79.txt
#   inflating: root/train/B9540E358F73.txt
#   inflating: root/train/B954492209C4.txt
#   inflating: root/train/B962DFFBD558.txt
#   inflating: root/train/B9653E66970E.txt
#   inflating: root/train/B967FC913839.txt
#   inflating: root/train/B9688F9C3150.txt
#   inflating: root/train/B970F5895E51.txt
#   inflating: root/train/B97A09B22C06.txt
#   inflating: root/train/B97CDCF8DBAA.txt
#   inflating: root/train/B97D96E80176.txt
#   inflating: root/train/B980EA7222ED.txt
#   inflating: root/train/B9854217BB04.txt
#   inflating: root/train/B9871E7972A3.txt
#   inflating: root/train/B989ECD8F137.txt
#   inflating: root/train/B98AD566DC48.txt
#   inflating: root/train/B98CEECCB8B7.txt
#   inflating: root/train/B996860E00A4.txt
#   inflating: root/train/B99A12610C04.txt
#   inflating: root/train/B99F89ED9463.txt
#   inflating: root/train/B9A542B2C36C.txt
#   inflating: root/train/B9B45507DDF8.txt
#   inflating: root/train/B9B653AD964E.txt
#   inflating: root/train/B9B8F5E753FB.txt
#   inflating: root/train/B9C3E87E3FEA.txt
#   inflating: root/train/B9CA103F2BF9.txt
#   inflating: root/train/B9CAFF9A9372.txt
#   inflating: root/train/B9D9B02EFC86.txt
#   inflating: root/train/B9DA369E6C5A.txt
#   inflating: root/train/B9DABCFD687D.txt
#   inflating: root/train/B9DC18D5931D.txt
#   inflating: root/train/B9E26FE6A3D7.txt
#   inflating: root/train/B9E9DC1D176F.txt
#   inflating: root/train/B9EEE56F7338.txt
#   inflating: root/train/B9EF80FFB58F.txt
#   inflating: root/train/B9F4BF3DC949.txt
#   inflating: root/train/B9F4C334368C.txt
#   inflating: root/train/B9FFF4311016.txt
#   inflating: root/train/B9FFFA708444.txt
#   inflating: root/train/BA007250F304.txt
#   inflating: root/train/BA0183CB23C5.txt
#   inflating: root/train/BA0B62C84ADD.txt
#   inflating: root/train/BA117C57D525.txt
#   inflating: root/train/BA13D9BB033E.txt
#   inflating: root/train/BA18C6F80423.txt
#   inflating: root/train/BA1D860F0A07.txt
#   inflating: root/train/BA1E2A47DC1B.txt
#   inflating: root/train/BA1F4C988D94.txt
#   inflating: root/train/BA2C7291BBFA.txt
#   inflating: root/train/BA30863CDECB.txt
#   inflating: root/train/BA38004E2A10.txt
#   inflating: root/train/BA3D6BB860C6.txt
#   inflating: root/train/BA43E40FDC33.txt
#   inflating: root/train/BA47D0FEA751.txt
#   inflating: root/train/BA4A641ED9A6.txt
#   inflating: root/train/BA4C6C9586DB.txt
#   inflating: root/train/BA4F5A7FACD7.txt
#   inflating: root/train/BA5056B8C67C.txt
#   inflating: root/train/BA541CCAA2FF.txt
#   inflating: root/train/BA545022DFCD.txt
#   inflating: root/train/BA587FF2351A.txt
#   inflating: root/train/BA591AF1C837.txt
#   inflating: root/train/BA596EB98749.txt
#   inflating: root/train/BA5C438CC087.txt
#   inflating: root/train/BA615AAC44E7.txt
#   inflating: root/train/BA655E4F7018.txt
#   inflating: root/train/BA6A9F0E5306.txt
#   inflating: root/train/BA6AC1A0DD5D.txt
#   inflating: root/train/BA6C6CE73F3C.txt
#   inflating: root/train/BA6CB0CBB691.txt
#   inflating: root/train/BA71F335957F.txt
#   inflating: root/train/BA72320741A4.txt
#   inflating: root/train/BA7FDE49E357.txt
#   inflating: root/train/BA85951767B0.txt
#   inflating: root/train/BA8756AB310B.txt
#   inflating: root/train/BA881F8A8909.txt
#   inflating: root/train/BA8A33501B62.txt
#   inflating: root/train/BA8BE010BFC6.txt
#   inflating: root/train/BA908A399CEB.txt
#   inflating: root/train/BA991FE296BD.txt
#   inflating: root/train/BA9B801E3540.txt
#   inflating: root/train/BAA77B0FC943.txt
#   inflating: root/train/BAAC43CEFCEE.txt
#   inflating: root/train/BAAE75D65C1D.txt
#   inflating: root/train/BAB0E8E2AE82.txt
#   inflating: root/train/BAB1B270B0A6.txt
#   inflating: root/train/BAB28ABA8ECE.txt
#   inflating: root/train/BAC0AA769B06.txt
#   inflating: root/train/BAC14C5693CD.txt
#   inflating: root/train/BAC30ACCEEFF.txt
#   inflating: root/train/BAC5264E2DCE.txt
#   inflating: root/train/BAC681996825.txt
#   inflating: root/train/BAC82DBE66F6.txt
#   inflating: root/train/BAC97C094725.txt
#   inflating: root/train/BACC53ECC1FB.txt
#   inflating: root/train/BAD0F52F3183.txt
#   inflating: root/train/BAD78C43D291.txt
#   inflating: root/train/BAE3CED482E7.txt
#   inflating: root/train/BAEE45819FA1.txt
#   inflating: root/train/BAF1A52A5380.txt
#   inflating: root/train/BAF6A144BAAF.txt
#   inflating: root/train/BAFC5102D2F5.txt
#   inflating: root/train/BB009CEC8D8F.txt
#   inflating: root/train/BB02D525CE05.txt
#   inflating: root/train/BB08150E3DAC.txt
#   inflating: root/train/BB12314FD64A.txt
#   inflating: root/train/BB131B5518F6.txt
#   inflating: root/train/BB1452CF4348.txt
#   inflating: root/train/BB1F8715BE8F.txt
#   inflating: root/train/BB207C714EBA.txt
#   inflating: root/train/BB2744686A59.txt
#   inflating: root/train/BB27E087BE9E.txt
#   inflating: root/train/BB281953DF01.txt
#   inflating: root/train/BB2AE006B7CF.txt
#   inflating: root/train/BB2D7EB6E8A3.txt
#   inflating: root/train/BB2E4FA20755.txt
#   inflating: root/train/BB33169642C3.txt
#   inflating: root/train/BB3615AA4AF1.txt
#   inflating: root/train/BB3A2E8DECCB.txt
#   inflating: root/train/BB3A6C2D0B65.txt
#   inflating: root/train/BB3EBEF87BBB.txt
#   inflating: root/train/BB485D0F7E4E.txt
#   inflating: root/train/BB4A53A0A9E0.txt
#   inflating: root/train/BB4B5D896E96.txt
#   inflating: root/train/BB5B7EE4A1A6.txt
#   inflating: root/train/BB6793327D1C.txt
#   inflating: root/train/BB6B3A9576D5.txt
#   inflating: root/train/BB6C3C9B743E.txt
#   inflating: root/train/BB705FBA29C7.txt
#   inflating: root/train/BB73F328D545.txt
#   inflating: root/train/BB788EF59B9E.txt
#   inflating: root/train/BB8064D7B327.txt
#   inflating: root/train/BB84B185AE32.txt
#   inflating: root/train/BB86A3A5AFE7.txt
#   inflating: root/train/BB86D8B194BD.txt
#   inflating: root/train/BB86D8C463AB.txt
#   inflating: root/train/BB870A7E5BC4.txt
#   inflating: root/train/BB8AADDCF097.txt
#   inflating: root/train/BB92579586BF.txt
#   inflating: root/train/BB95D06EF8D4.txt
#   inflating: root/train/BB9B2400BE18.txt
#   inflating: root/train/BB9E9FAB601B.txt
#   inflating: root/train/BBA628314474.txt
#   inflating: root/train/BBB0C6DD06E5.txt
#   inflating: root/train/BBB54BC8F12C.txt
#   inflating: root/train/BBB6E0302CFE.txt
#   inflating: root/train/BBBB5C4705E5.txt
#   inflating: root/train/BBBC74680147.txt
#   inflating: root/train/BBBF0CA12DE1.txt
#   inflating: root/train/BBC0E1AA58C9.txt
#   inflating: root/train/BBC71057F9A5.txt
#   inflating: root/train/BBC740F1DC57.txt
#   inflating: root/train/BBDA39C84AF7.txt
#   inflating: root/train/BBDD46456082.txt
#   inflating: root/train/BBE0D2A103B3.txt
#   inflating: root/train/BBE1713D653B.txt
#   inflating: root/train/BBE712F7271D.txt
#   inflating: root/train/BBEB4231A8AF.txt
#   inflating: root/train/BBEE06BD484C.txt
#   inflating: root/train/BBF34C059226.txt
#   inflating: root/train/BC00D6BD8AEF.txt
#   inflating: root/train/BC0703638937.txt
#   inflating: root/train/BC0B8B8E499F.txt
#   inflating: root/train/BC0D8223C604.txt
#   inflating: root/train/BC0D9F77A3DA.txt
#   inflating: root/train/BC100C3DCE76.txt
#   inflating: root/train/BC14D201CBF5.txt
#   inflating: root/train/BC18DF62AF2A.txt
#   inflating: root/train/BC2210868DF6.txt
#   inflating: root/train/BC22AA8852AD.txt
#   inflating: root/train/BC2333002957.txt
#   inflating: root/train/BC27CDCD1A45.txt
#   inflating: root/train/BC28F86E7C15.txt
#   inflating: root/train/BC2CAB7DB6F0.txt
#   inflating: root/train/BC32404D0719.txt
#   inflating: root/train/BC3BA3BD592F.txt
#   inflating: root/train/BC4CC859C08D.txt
#   inflating: root/train/BC5B1BBADA5D.txt
#   inflating: root/train/BC61B07C351D.txt
#   inflating: root/train/BC73CEB66875.txt
#   inflating: root/train/BC7CD211742E.txt
#   inflating: root/train/BC8237E7AC1E.txt
#   inflating: root/train/BC8ABD92AC4D.txt
#   inflating: root/train/BC9FF8F01F0A.txt
#   inflating: root/train/BCA46E5E0515.txt
#   inflating: root/train/BCA57CE2AFA3.txt
#   inflating: root/train/BCA9ED73877E.txt
#   inflating: root/train/BCAE5B0783CF.txt
#   inflating: root/train/BCB916A9A9F3.txt
#   inflating: root/train/BCC1433ECAEB.txt
#   inflating: root/train/BCC7A516F7C8.txt
#   inflating: root/train/BCCBDC331659.txt
#   inflating: root/train/BCD1EF2F248C.txt
#   inflating: root/train/BCDD31180F50.txt
#   inflating: root/train/BCE83D08D2D5.txt
#   inflating: root/train/BCEBA1D60DFD.txt
#   inflating: root/train/BCEBC0EB9F21.txt
#   inflating: root/train/BCED11FF41CE.txt
#   inflating: root/train/BCEF4D5FF6AB.txt
#   inflating: root/train/BCF1394768B1.txt
#   inflating: root/train/BCF95C5F4A60.txt
#   inflating: root/train/BD06C543C1FC.txt
#   inflating: root/train/BD0A4A94AC7B.txt
#   inflating: root/train/BD0D555216AB.txt
#   inflating: root/train/BD0D7907E4D7.txt
#   inflating: root/train/BD128A3C6F33.txt
#   inflating: root/train/BD195459F3B9.txt
#   inflating: root/train/BD2F55C5A538.txt
#   inflating: root/train/BD300B07564D.txt
#   inflating: root/train/BD304A35EE44.txt
#   inflating: root/train/BD33192DA18E.txt
#   inflating: root/train/BD3AE65B1740.txt
#   inflating: root/train/BD45F6A61711.txt
#   inflating: root/train/BD4A81EA9360.txt
#   inflating: root/train/BD4B01D328B0.txt
#   inflating: root/train/BD4BFB4E8C6B.txt
#   inflating: root/train/BD608B2E9079.txt
#   inflating: root/train/BD6CCC592409.txt
#   inflating: root/train/BD784C4B5797.txt
#   inflating: root/train/BD7D972ED5B5.txt
#   inflating: root/train/BD7F5D94AFED.txt
#   inflating: root/train/BD82629E71E2.txt
#   inflating: root/train/BD889A4D831B.txt
#   inflating: root/train/BD88FF0A458D.txt
#   inflating: root/train/BD891970FC4A.txt
#   inflating: root/train/BDA93024CF81.txt
#   inflating: root/train/BDAAE2AE7BA8.txt
#   inflating: root/train/BDB04C58DD28.txt
#   inflating: root/train/BDBB3AF5C30A.txt
#   inflating: root/train/BDC4070CF21E.txt
#   inflating: root/train/BDC47D47817A.txt
#   inflating: root/train/BDCD981437BB.txt
#   inflating: root/train/BDD42FCF1F34.txt
#   inflating: root/train/BDD5D74671DD.txt
#   inflating: root/train/BDD65CF27087.txt
#   inflating: root/train/BDDD49DF0C7D.txt
#   inflating: root/train/BDE08546F7EE.txt
#   inflating: root/train/BDE41F0B5A4A.txt
#   inflating: root/train/BDE4475D7290.txt
#   inflating: root/train/BDE777E6A89A.txt
#   inflating: root/train/BDEAAFE68AA1.txt
#   inflating: root/train/BDEFD408149D.txt
#   inflating: root/train/BDF7794E56BF.txt
#   inflating: root/train/BDFEDD161F03.txt
#   inflating: root/train/BE01ACCDF251.txt
#   inflating: root/train/BE04A735B0C5.txt
#   inflating: root/train/BE06AE84DE6F.txt
#   inflating: root/train/BE077517E449.txt
#   inflating: root/train/BE090988C5A1.txt
#   inflating: root/train/BE0B11659D82.txt
#   inflating: root/train/BE126D453657.txt
#   inflating: root/train/BE1271291C2D.txt
#   inflating: root/train/BE12A65C8E78.txt
#   inflating: root/train/BE134CD245B0.txt
#   inflating: root/train/BE1367FA4958.txt
#   inflating: root/train/BE1752DCF09C.txt
#   inflating: root/train/BE1E07640466.txt
#   inflating: root/train/BE1F20C5B099.txt
#   inflating: root/train/BE243683124A.txt
#   inflating: root/train/BE24907D6684.txt
#   inflating: root/train/BE28ACA50D03.txt
#   inflating: root/train/BE2CBE1F52EE.txt
#   inflating: root/train/BE2DEC1820C6.txt
#   inflating: root/train/BE34F8528793.txt
#   inflating: root/train/BE3908E29A1D.txt
#   inflating: root/train/BE3B47A38A44.txt
#   inflating: root/train/BE3CDD3C096D.txt
#   inflating: root/train/BE400D3E9018.txt
#   inflating: root/train/BE43251A1D82.txt
#   inflating: root/train/BE464F52C63D.txt
#   inflating: root/train/BE4764F7BFF1.txt
#   inflating: root/train/BE48D8480173.txt
#   inflating: root/train/BE491CB91FD3.txt
#   inflating: root/train/BE4E34FD45B6.txt
#   inflating: root/train/BE58ABE09429.txt
#   inflating: root/train/BE5B1803777E.txt
#   inflating: root/train/BE5D3ADC4F2B.txt
#   inflating: root/train/BE604A32144C.txt
#   inflating: root/train/BE62C5534E8B.txt
#   inflating: root/train/BE68B9E53CCB.txt
#   inflating: root/train/BE694C1289EF.txt
#   inflating: root/train/BE6A7B809487.txt
#   inflating: root/train/BE6A9A5A2824.txt
#   inflating: root/train/BE6D18BAA3D1.txt
#   inflating: root/train/BE6FC06B8795.txt
#   inflating: root/train/BE803DB36DBC.txt
#   inflating: root/train/BE80D73EC131.txt
#   inflating: root/train/BE88F40828C4.txt
#   inflating: root/train/BE8F32C4B3BA.txt
#   inflating: root/train/BE94CF981273.txt
#   inflating: root/train/BE9761F227C5.txt
#   inflating: root/train/BE9881C4920A.txt
#   inflating: root/train/BEAA8D8A3EFD.txt
#   inflating: root/train/BEAD93DDDB69.txt
#   inflating: root/train/BEB1900622E4.txt
#   inflating: root/train/BEB797E37AB6.txt
#   inflating: root/train/BEBA66D273BC.txt
#   inflating: root/train/BEBB31733A38.txt
#   inflating: root/train/BEC46C36BC47.txt
#   inflating: root/train/BEC88463148B.txt
#   inflating: root/train/BECA14914CFB.txt
#   inflating: root/train/BECFCA5BFABD.txt
#   inflating: root/train/BED033B2C361.txt
#   inflating: root/train/BED3F52C69F9.txt
#   inflating: root/train/BEDC43C0FE6A.txt
#   inflating: root/train/BEDE9BA3773B.txt
#   inflating: root/train/BEDEBC52CD1A.txt
#   inflating: root/train/BEE16EB0ACF4.txt
#   inflating: root/train/BEE1B9179E2C.txt
#   inflating: root/train/BEE3471F7F15.txt
#   inflating: root/train/BEE54D4D2B79.txt
#   inflating: root/train/BEE6B76959CE.txt
#   inflating: root/train/BEEE3AC55C0E.txt
#   inflating: root/train/BEF460B090E0.txt
#   inflating: root/train/BEF5E55E29CB.txt
#   inflating: root/train/BEFEAAA5B388.txt
#   inflating: root/train/BF00A0DFDA72.txt
#   inflating: root/train/BF01FFEF8CB3.txt
#   inflating: root/train/BF021AC4EF38.txt
#   inflating: root/train/BF0241C10324.txt
#   inflating: root/train/BF040431FB95.txt
#   inflating: root/train/BF070C66EE96.txt
#   inflating: root/train/BF07A20CFE46.txt
#   inflating: root/train/BF08EB9EBE3D.txt
#   inflating: root/train/BF0ADF374100.txt
#   inflating: root/train/BF0D14D14F35.txt
#   inflating: root/train/BF17866F7014.txt
#   inflating: root/train/BF181ED1EC7E.txt
#   inflating: root/train/BF195B6C980A.txt
#   inflating: root/train/BF205C369289.txt
#   inflating: root/train/BF21FE121718.txt
#   inflating: root/train/BF295AF91B15.txt
#   inflating: root/train/BF2B46872736.txt
#   inflating: root/train/BF2C64DF2CC8.txt
#   inflating: root/train/BF2D36E0B64B.txt
#   inflating: root/train/BF2E86982E3A.txt
#   inflating: root/train/BF3728CF3A98.txt
#   inflating: root/train/BF3C81A48FFC.txt
#   inflating: root/train/BF3CC3305C55.txt
#   inflating: root/train/BF3EE6D66E3D.txt
#   inflating: root/train/BF45A993373E.txt
#   inflating: root/train/BF4BD008BA9E.txt
#   inflating: root/train/BF4D8E461594.txt
#   inflating: root/train/BF5253224A44.txt
#   inflating: root/train/BF5384FC042A.txt
#   inflating: root/train/BF5D82D486F5.txt
#   inflating: root/train/BF5E801B7FD6.txt
#   inflating: root/train/BF619ADE9BF4.txt
#   inflating: root/train/BF7C67E62F30.txt
#   inflating: root/train/BF7DA06D503F.txt
#   inflating: root/train/BF8116051B9D.txt
#   inflating: root/train/BF960F59D07C.txt
#   inflating: root/train/BF97DBDFC416.txt
#   inflating: root/train/BF9875A149DE.txt
#   inflating: root/train/BF9A3A65135E.txt
#   inflating: root/train/BF9D28CEA717.txt
#   inflating: root/train/BFA04D3BB1B5.txt
#   inflating: root/train/BFA4685DCDC6.txt
#   inflating: root/train/BFA653493276.txt
#   inflating: root/train/BFA71BBF3536.txt
#   inflating: root/train/BFA821713F92.txt
#   inflating: root/train/BFA9F9B90BFB.txt
#   inflating: root/train/BFAA8D19FFA9.txt
# ...
#   inflating: root/train/FA058ADBE64F.txt
#   inflating: root/train/FA05B7CD828D.txt
#   inflating: root/train/FA130E0C813E.txt
#   inflating: root/train/FA138B97C15F.txt
#   inflating: root/train/FA15A1E3BF2C.txt
#   inflating: root/train/FA1B10147C1C.txt
#   inflating: root/train/FA1CE35CA43F.txt
#   inflating: root/train/FA1E56F220C0.txt
#   inflating: root/train/FA1E97DAA131.txt
#   inflating: root/train/FA205817C3C5.txt
#   inflating: root/train/FA20F1758F03.txt
#   inflating: root/train/FA2BC6C3A09B.txt
#   inflating: root/train/FA3007D9CDA6.txt
#   inflating: root/train/FA34C91658A9.txt
#   inflating: root/train/FA35444BD9C6.txt
#   inflating: root/train/FA363FC0B71E.txt
#   inflating: root/train/FA38B62F80E5.txt
#   inflating: root/train/FA3922F67FAB.txt
#   inflating: root/train/FA3BDEECBD44.txt
#   inflating: root/train/FA3E37900E3D.txt
#   inflating: root/train/FA3E50D30004.txt
#   inflating: root/train/FA4200AB1CBC.txt
#   inflating: root/train/FA483ED371E7.txt
#   inflating: root/train/FA49F4D9E6A8.txt
#   inflating: root/train/FA4E66C7BC61.txt
#   inflating: root/train/FA4FE7706A1A.txt
#   inflating: root/train/FA5043677B2F.txt
#   inflating: root/train/FA50C9D9F031.txt
#   inflating: root/train/FA56641252C3.txt
#   inflating: root/train/FA56A00B0CC8.txt
#   inflating: root/train/FA5708DBC13C.txt
#   inflating: root/train/FA591109B448.txt
#   inflating: root/train/FA5C17345A74.txt
#   inflating: root/train/FA5CE3A393CF.txt
#   inflating: root/train/FA5D64EC3C72.txt
#   inflating: root/train/FA625035B96F.txt
#   inflating: root/train/FA62EE04FAFA.txt
#   inflating: root/train/FA63A2D4191E.txt
#   inflating: root/train/FA6AF2AFC743.txt
#   inflating: root/train/FA6FD7F076C6.txt
#   inflating: root/train/FA7A5EC25DDE.txt
#   inflating: root/train/FA7B0CD8DC92.txt
#   inflating: root/train/FA8735E99D14.txt
#   inflating: root/train/FA87416EF173.txt
#   inflating: root/train/FAA1621106BE.txt
#   inflating: root/train/FAA638E881EB.txt
#   inflating: root/train/FAA7B824C589.txt
#   inflating: root/train/FAA9FC1B315B.txt
#   inflating: root/train/FAAC3CC5476F.txt
#   inflating: root/train/FAB02B654C4E.txt
#   inflating: root/train/FAB2A6A368E5.txt
#   inflating: root/train/FAB2E7DB60B1.txt
#   inflating: root/train/FAB4AD7890A9.txt
#   inflating: root/train/FAB88954B1AF.txt
#   inflating: root/train/FABCC1785BB9.txt
#   inflating: root/train/FABE0E966789.txt
#   inflating: root/train/FABEC779D19E.txt
#   inflating: root/train/FABF3E8A5B27.txt
#   inflating: root/train/FAC1A3B4097F.txt
#   inflating: root/train/FACA3592FCD0.txt
#   inflating: root/train/FACC34F1875E.txt
#   inflating: root/train/FACC93B5A80A.txt
#   inflating: root/train/FACF20D0D847.txt
#   inflating: root/train/FAD0AE0CA89B.txt
#   inflating: root/train/FAE077D9355F.txt
#   inflating: root/train/FAE1A7023F1F.txt
#   inflating: root/train/FAE3AC62234D.txt
#   inflating: root/train/FAE64D6D08BA.txt
#   inflating: root/train/FAEA2DFB9ADB.txt
#   inflating: root/train/FAEF7499B133.txt
#   inflating: root/train/FAF28CA70259.txt
#   inflating: root/train/FAF658D1034B.txt
#   inflating: root/train/FAF7BA5CEB25.txt
#   inflating: root/train/FAF91DDF582C.txt
#   inflating: root/train/FAF9437BCC50.txt
#   inflating: root/train/FAFDA54C78E1.txt
#   inflating: root/train/FAFFAC27CA05.txt
#   inflating: root/train/FB0053511F2F.txt
#   inflating: root/train/FB0404CADC51.txt
#   inflating: root/train/FB05272DAD57.txt
#   inflating: root/train/FB07A07B9082.txt
#   inflating: root/train/FB11E7AFA373.txt
#   inflating: root/train/FB14FF43E876.txt
#   inflating: root/train/FB1553163CF5.txt
#   inflating: root/train/FB1DB922DE1B.txt
#   inflating: root/train/FB206BA12858.txt
#   inflating: root/train/FB2ED8D952A6.txt
#   inflating: root/train/FB3004826640.txt
#   inflating: root/train/FB3850CF775C.txt
#   inflating: root/train/FB467AFF2BBF.txt
#   inflating: root/train/FB4C199449F3.txt
#   inflating: root/train/FB4EAE59106B.txt
#   inflating: root/train/FB4EBC7AAF6E.txt
#   inflating: root/train/FB5189EE173C.txt
#   inflating: root/train/FB528A6DAF0C.txt
#   inflating: root/train/FB56AA75F65F.txt
#   inflating: root/train/FB5D79B7573C.txt
#   inflating: root/train/FB68F4744D15.txt
#   inflating: root/train/FB6A513EBFC6.txt
#   inflating: root/train/FB6C139752AA.txt
#   inflating: root/train/FB6D4F0A03CD.txt
#   inflating: root/train/FB7A0BB5DBE4.txt
#   inflating: root/train/FB7A42A10DCE.txt
#   inflating: root/train/FB7DB9D91933.txt
#   inflating: root/train/FB7E9462C5A1.txt
#   inflating: root/train/FB84390667B1.txt
#   inflating: root/train/FB8549B2A141.txt
#   inflating: root/train/FB8A6D53974D.txt
#   inflating: root/train/FB8C67F0AC92.txt
#   inflating: root/train/FB8E886E748C.txt
#   inflating: root/train/FB8F29B936CE.txt
#   inflating: root/train/FB946CB635AC.txt
#   inflating: root/train/FB9569BDE4BB.txt
#   inflating: root/train/FB9CE02393F9.txt
#   inflating: root/train/FBA0A3C464EB.txt
#   inflating: root/train/FBA3B87A37EA.txt
#   inflating: root/train/FBA695DE1944.txt
#   inflating: root/train/FBA94EEA61BF.txt
#   inflating: root/train/FBABC3FB451D.txt
#   inflating: root/train/FBB35C3EF339.txt
#   inflating: root/train/FBB861DBF984.txt
#   inflating: root/train/FBBA870588CC.txt
#   inflating: root/train/FBBA8C2C378A.txt
#   inflating: root/train/FBC1CA161C5F.txt
#   inflating: root/train/FBC4F9ADED9A.txt
#   inflating: root/train/FBC7DC3C27C0.txt
#   inflating: root/train/FBC98CE96EB2.txt
#   inflating: root/train/FBCFA4D35602.txt
#   inflating: root/train/FBD01BF7E929.txt
#   inflating: root/train/FBD21BB50633.txt
#   inflating: root/train/FBD852FCA5C1.txt
#   inflating: root/train/FBDCEEB8E7BD.txt
#   inflating: root/train/FBDEE9B13087.txt
#   inflating: root/train/FBE13E9A446C.txt
#   inflating: root/train/FBE4AAD08E49.txt
#   inflating: root/train/FBE8983EF69C.txt
#   inflating: root/train/FBF5936A2053.txt
#   inflating: root/train/FBF6DE55FBB7.txt
#   inflating: root/train/FBFA1FD8E2F1.txt
#   inflating: root/train/FBFAA80ADC60.txt
#   inflating: root/train/FBFF39C1F504.txt
#   inflating: root/train/FBFF8161ACAC.txt
#   inflating: root/train/FC01486A3507.txt
#   inflating: root/train/FC0C60D3B9B1.txt
#   inflating: root/train/FC1196671EE9.txt
#   inflating: root/train/FC15D48EB587.txt
#   inflating: root/train/FC1E77760D5F.txt
#   inflating: root/train/FC273A287819.txt
#   inflating: root/train/FC27ECB471A4.txt
#   inflating: root/train/FC2EF19C51AC.txt
#   inflating: root/train/FC39D2688C50.txt
#   inflating: root/train/FC3BD2A0D23E.txt
#   inflating: root/train/FC3E4DED2064.txt
#   inflating: root/train/FC44783E32EE.txt
#   inflating: root/train/FC481B7DC611.txt
#   inflating: root/train/FC48F3633C23.txt
#   inflating: root/train/FC492DC3D1D3.txt
#   inflating: root/train/FC4E9C36D5BC.txt
#   inflating: root/train/FC4FBC43EF32.txt
#   inflating: root/train/FC5120C98AE7.txt
#   inflating: root/train/FC5C7E89577A.txt
#   inflating: root/train/FC623FF64C7D.txt
#   inflating: root/train/FC63C08CEC27.txt
#   inflating: root/train/FC6F09041098.txt
#   inflating: root/train/FC73A83CF59C.txt
#   inflating: root/train/FC79A21481C3.txt
#   inflating: root/train/FC79A84D783B.txt
#   inflating: root/train/FC7A3692794B.txt
#   inflating: root/train/FC8DD899209B.txt
#   inflating: root/train/FC90D46FBE1F.txt
#   inflating: root/train/FC970909BA69.txt
#   inflating: root/train/FC97FB8F850C.txt
#   inflating: root/train/FC995D1D61C9.txt
#   inflating: root/train/FC9BC150809F.txt
#   inflating: root/train/FC9DA73D1EA0.txt
#   inflating: root/train/FC9E2A38AFBB.txt
#   inflating: root/train/FCA226021172.txt
#   inflating: root/train/FCA553D1B819.txt
#   inflating: root/train/FCB06E87281B.txt
#   inflating: root/train/FCB208A4710C.txt
#   inflating: root/train/FCB492F7425D.txt
#   inflating: root/train/FCB9D3E12BAF.txt
#   inflating: root/train/FCBD4BC9112B.txt
#   inflating: root/train/FCC49A3C15F5.txt
#   inflating: root/train/FCD5E2EA7372.txt
#   inflating: root/train/FCD8E0AB7133.txt
#   inflating: root/train/FCEC225CA2D0.txt
#   inflating: root/train/FCEF76504A79.txt
#   inflating: root/train/FCEFFF74C652.txt
#   inflating: root/train/FCF3A5BD8371.txt
#   inflating: root/train/FCF5D3ED5218.txt
#   inflating: root/train/FCF6588BC52B.txt
#   inflating: root/train/FCF9802D7F21.txt
#   inflating: root/train/FCFD10916659.txt
#   inflating: root/train/FD0061B1786E.txt
#   inflating: root/train/FD011A2C9C3B.txt
#   inflating: root/train/FD05FDCEA11B.txt
#   inflating: root/train/FD0934F5261D.txt
#   inflating: root/train/FD0C32EA0E5B.txt
#   inflating: root/train/FD100E530592.txt
#   inflating: root/train/FD1511BE7AD2.txt
#   inflating: root/train/FD175811A893.txt
#   inflating: root/train/FD1869C76891.txt
#   inflating: root/train/FD1C07651D9A.txt
#   inflating: root/train/FD311907E3DB.txt
#   inflating: root/train/FD361491E6FA.txt
#   inflating: root/train/FD38779AFF13.txt
#   inflating: root/train/FD3BDEB06028.txt
#   inflating: root/train/FD48976C9913.txt
#   inflating: root/train/FD48D4BB6F06.txt
#   inflating: root/train/FD5347E3C97B.txt
#   inflating: root/train/FD5415D63B9A.txt
#   inflating: root/train/FD562A12092E.txt
#   inflating: root/train/FD5AF33900D9.txt
#   inflating: root/train/FD5C0FE5FE53.txt
#   inflating: root/train/FD5F79937C4E.txt
#   inflating: root/train/FD65FEAAB0BC.txt
#   inflating: root/train/FD6E0C78E9BB.txt
#   inflating: root/train/FD77C6694E4A.txt
#   inflating: root/train/FD7EFCCA4C5B.txt
#   inflating: root/train/FD84DB08498A.txt
#   inflating: root/train/FD883FB88BA1.txt
#   inflating: root/train/FD8A2F2EBCFA.txt
#   inflating: root/train/FD8A9514C8BC.txt
#   inflating: root/train/FD8B18756C68.txt
#   inflating: root/train/FD8DA401BE5D.txt
#   inflating: root/train/FD8FFDC82D48.txt
#   inflating: root/train/FD918AF59BD3.txt
#   inflating: root/train/FD942066A558.txt
#   inflating: root/train/FD97228DE00F.txt
#   inflating: root/train/FD998A2E69A5.txt
#   inflating: root/train/FD9C10176D2A.txt
#   inflating: root/train/FD9CC83A98C5.txt
#   inflating: root/train/FDA09342D0C4.txt
#   inflating: root/train/FDABEB626A28.txt
#   inflating: root/train/FDB27AC9357D.txt
#   inflating: root/train/FDBC5C68ED9F.txt
#   inflating: root/train/FDC077398F13.txt
#   inflating: root/train/FDC5C6E0B4A7.txt
#   inflating: root/train/FDC60E5A9011.txt
#   inflating: root/train/FDCBCA9B0636.txt
#   inflating: root/train/FDD398F4D5E9.txt
#   inflating: root/train/FDD7D9AA0940.txt
#   inflating: root/train/FDD81292D8A4.txt
#   inflating: root/train/FDD92DC5BCBD.txt
#   inflating: root/train/FDE359A2F973.txt
#   inflating: root/train/FDF0AEEB14C3.txt
#   inflating: root/train/FDF36AD8FC91.txt
#   inflating: root/train/FDFDA7D3B93A.txt
#   inflating: root/train/FDFE18598112.txt
#   inflating: root/train/FE018F15F8A4.txt
#   inflating: root/train/FE01BAE235A1.txt
#   inflating: root/train/FE0B381BC161.txt
#   inflating: root/train/FE0F75B1CFFD.txt
#   inflating: root/train/FE1203E26CAC.txt
#   inflating: root/train/FE129177A067.txt
#   inflating: root/train/FE133737091E.txt
#   inflating: root/train/FE15824E02F0.txt
#   inflating: root/train/FE185C099C92.txt
#   inflating: root/train/FE19167C0BF8.txt
#   inflating: root/train/FE1DEACABE37.txt
#   inflating: root/train/FE1F2A5377EF.txt
#   inflating: root/train/FE21B0B76C9C.txt
#   inflating: root/train/FE3141FA4163.txt
#   inflating: root/train/FE38B23D5585.txt
#   inflating: root/train/FE3973324F8B.txt
#   inflating: root/train/FE3CA06DDCA1.txt
#   inflating: root/train/FE406101C12C.txt
#   inflating: root/train/FE409DDFA2C2.txt
#   inflating: root/train/FE40A50DF994.txt
#   inflating: root/train/FE4703854EB4.txt
#   inflating: root/train/FE47325AD93F.txt
#   inflating: root/train/FE477BD61B22.txt
#   inflating: root/train/FE56E3645667.txt
#   inflating: root/train/FE604F4C35DC.txt
#   inflating: root/train/FE6113EF0938.txt
#   inflating: root/train/FE62304F4B86.txt
#   inflating: root/train/FE69FBDD5681.txt
#   inflating: root/train/FE72572BE11A.txt
#   inflating: root/train/FE74E08F6F0D.txt
#   inflating: root/train/FE753233249B.txt
#   inflating: root/train/FE8900F731E7.txt
#   inflating: root/train/FE8FBB812AC6.txt
#   inflating: root/train/FE91D719ADAC.txt
#   inflating: root/train/FE9AB60822CA.txt
#   inflating: root/train/FE9C4B960A19.txt
#   inflating: root/train/FE9E14F641F8.txt
#   inflating: root/train/FEA33BCE1FB3.txt
#   inflating: root/train/FEA516299C94.txt
#   inflating: root/train/FEAE1B329876.txt
#   inflating: root/train/FEB37659C3F1.txt
#   inflating: root/train/FEB736959AD7.txt
#   inflating: root/train/FEBFD34B8021.txt
#   inflating: root/train/FEC518CC5F94.txt
#   inflating: root/train/FECF4BCDDE02.txt
#   inflating: root/train/FED2903D0697.txt
#   inflating: root/train/FED30EC0C032.txt
#   inflating: root/train/FED359DCA0BF.txt
#   inflating: root/train/FED42BB10805.txt
#   inflating: root/train/FED49579044F.txt
#   inflating: root/train/FED925296F42.txt
#   inflating: root/train/FEDA46BB37A7.txt
#   inflating: root/train/FEE1811CCE57.txt
#   inflating: root/train/FEE59DA64E91.txt
#   inflating: root/train/FEEA679DCBB3.txt
#   inflating: root/train/FEF2CAFB3483.txt
#   inflating: root/train/FEF2E1612F55.txt
#   inflating: root/train/FEF334C14BAE.txt
#   inflating: root/train/FEF42864AE28.txt
#   inflating: root/train/FEFB6689114B.txt
#   inflating: root/train/FF01B32BAC3E.txt
#   inflating: root/train/FF07E6BF0858.txt
#   inflating: root/train/FF0FCC95E73F.txt
#   inflating: root/train/FF11B4681D78.txt
#   inflating: root/train/FF13996AB0B3.txt
#   inflating: root/train/FF145B5C5E4D.txt
#   inflating: root/train/FF15470AABF0.txt
#   inflating: root/train/FF162F4E5289.txt
#   inflating: root/train/FF197A6B15B2.txt
#   inflating: root/train/FF1FAA91122E.txt
#   inflating: root/train/FF21CAA2F125.txt
#   inflating: root/train/FF21DC2805A9.txt
#   inflating: root/train/FF23EEEB0945.txt
#   inflating: root/train/FF2FC2AD8675.txt
#   inflating: root/train/FF30791C1A12.txt
#   inflating: root/train/FF35257B6394.txt
#   inflating: root/train/FF3F4514BF85.txt
#   inflating: root/train/FF4095394AA0.txt
#   inflating: root/train/FF410031A764.txt
#   inflating: root/train/FF447138621D.txt
#   inflating: root/train/FF489A3E4041.txt
#   inflating: root/train/FF4A215D86BF.txt
#   inflating: root/train/FF4C6C6FDB91.txt
#   inflating: root/train/FF5969F5A2EB.txt
#   inflating: root/train/FF5FC173E506.txt
#   inflating: root/train/FF6086271D2B.txt
#   inflating: root/train/FF62E6972211.txt
#   inflating: root/train/FF6B7128255A.txt
#   inflating: root/train/FF6E114981D0.txt
#   inflating: root/train/FF7164909305.txt
#   inflating: root/train/FF71B53EC31F.txt
#   inflating: root/train/FF762DF8E150.txt
#   inflating: root/train/FF7ADCC6146A.txt
#   inflating: root/train/FF7AFA7FF8B6.txt
#   inflating: root/train/FF7BA63A1993.txt
#   inflating: root/train/FF7D68D31981.txt
#   inflating: root/train/FF7E2F5C21CC.txt
#   inflating: root/train/FF8AC9C34B6D.txt
#   inflating: root/train/FF8BAC351714.txt
#   inflating: root/train/FF9114183593.txt
#   inflating: root/train/FF9202FAA566.txt
#   inflating: root/train/FF945B27A8F2.txt
#   inflating: root/train/FF9684AB0131.txt
#   inflating: root/train/FF9DB9D43F72.txt
#   inflating: root/train/FF9E0379CD98.txt
#   inflating: root/train/FF9E159AEEF0.txt
#   inflating: root/train/FFA381E58FC6.txt
#   inflating: root/train/FFA6D576449B.txt
#   inflating: root/train/FFACF4B90AB1.txt
#   inflating: root/train/FFBA3014CDC7.txt
#   inflating: root/train/FFC43F453EF6.txt
#   inflating: root/train/FFC88C06EFF6.txt
#   inflating: root/train/FFC8A1F3CE94.txt
#   inflating: root/train/FFD97A99CEBA.txt
#   inflating: root/train/FFDC850C3652.txt
#   inflating: root/train/FFE46004CDFB.txt
#   inflating: root/train/FFE4B98E0B1E.txt
#   inflating: root/train/FFF1442D6698.txt
#   inflating: root/train/FFF1ED4F8544.txt
#   inflating: root/train/FFF868E06176.txt
#   inflating: root/train/FFFD0AF13501.txt
#   inflating: root/train/FFFF80B8CC2F.txt

# %%
class args:
    fold = 0
    model = 'allenai/longformer-large-4096-finetuned-triviaqa'
    lr = 1e-5
    epochs = 5
    output = './'
    input = "/content/root"
    tez_model= "../input/fblongformerlarge1536/"
    output = "."
    batch_size = 1
    valid_batch_size = 2
    max_len = 2048 
    accumulation_steps = 1

# %%
import copy
import os

import numpy as np
import pandas as pd
import torch
from joblib import Parallel, delayed
from tez import enums
from tez.callbacks import Callback
from tqdm import tqdm

target_id_map = {
    "B-Lead": 0,
    "I-Lead": 1,
    "B-Position": 2,
    "I-Position": 3,
    "B-Evidence": 4,
    "I-Evidence": 5,
    "B-Claim": 6,
    "I-Claim": 7,
    "B-Concluding Statement": 8,
    "I-Concluding Statement": 9,
    "B-Counterclaim": 10,
    "I-Counterclaim": 11,
    "B-Rebuttal": 12,
    "I-Rebuttal": 13,
    "O": 14,
    "PAD": -100,
}


id_target_map = {v: k for k, v in target_id_map.items()}


def _prepare_training_data_helper(args, tokenizer, df, train_ids):
    training_samples = []
    for idx in tqdm(train_ids):
        filename = os.path.join(args.input, "train", idx + ".txt")
        with open(filename, "r") as f:
            text = f.read()
        prev_text = text
        text = spell(text)
        encoded_text = tokenizer.encode_plus(
            text,
            add_special_tokens=False,
            return_offsets_mapping=True,
        )
        input_ids = encoded_text["input_ids"]
        input_labels = copy.deepcopy(input_ids)
        offset_mapping = encoded_text["offset_mapping"]

        for k in range(len(input_labels)):
            input_labels[k] = "O"

        sample = {
            "id": idx,
            "input_ids": input_ids,
            "text": text,
            "offset_mapping": offset_mapping,
        }

        temp_df = df[df["id"] == idx]
        for _, row in temp_df.iterrows():
            text_labels = [0] * len(text)
            discourse_start = int(row["discourse_start"])
            discourse_end = int(row["discourse_end"])
            prediction_label = row["discourse_type"]
            text_labels[discourse_start:discourse_end] = [1] * (discourse_end - discourse_start)
            target_idx = []
            for map_idx, (offset1, offset2) in enumerate(encoded_text["offset_mapping"]):
                if sum(text_labels[offset1:offset2]) > 0:
                    if len(text[offset1:offset2].split()) > 0:
                        target_idx.append(map_idx)
            try:
                targets_start = target_idx[0]
            except:
                print(prev_text)
                print(text)
            targets_end = target_idx[-1]
            pred_start = "B-" + prediction_label
            pred_end = "I-" + prediction_label
            input_labels[targets_start] = pred_start
            input_labels[targets_start + 1 : targets_end + 1] = [pred_end] * (targets_end - targets_start)

        sample["input_ids"] = input_ids
        sample["input_labels"] = input_labels
        training_samples.append(sample)
    return training_samples


def prepare_training_data(df, tokenizer, args, num_jobs):
    training_samples = []
    train_ids = df["id"].unique()

    train_ids_splits = np.array_split(train_ids, num_jobs)

    results = Parallel(n_jobs=num_jobs, backend="multiprocessing")(
        delayed(_prepare_training_data_helper)(args, tokenizer, df, idx) for idx in train_ids_splits
    )
    for result in results:
        training_samples.extend(result)

    return training_samples


def calc_overlap(row):
    """
    Calculates the overlap between prediction and
    ground truth and overlap percentages used for determining
    true positives.
    """
    set_pred = set(row.predictionstring_pred.split(" "))
    set_gt = set(row.predictionstring_gt.split(" "))
    # Length of each and intersection
    len_gt = len(set_gt)
    len_pred = len(set_pred)
    inter = len(set_gt.intersection(set_pred))
    overlap_1 = inter / len_gt
    overlap_2 = inter / len_pred
    return [overlap_1, overlap_2]


def score_feedback_comp_micro(pred_df, gt_df):
    """
    A function that scores for the kaggle
        Student Writing Competition
    Uses the steps in the evaluation page here:
        https://www.kaggle.com/c/feedback-prize-2021/overview/evaluation
    This code is from Rob Mulla's Kaggle kernel.
    """
    gt_df = gt_df[["id", "discourse_type", "predictionstring"]].reset_index(drop=True).copy()
    pred_df = pred_df[["id", "class", "predictionstring"]].reset_index(drop=True).copy()
    pred_df["pred_id"] = pred_df.index
    gt_df["gt_id"] = gt_df.index
    # Step 1. all ground truths and predictions for a given class are compared.
    joined = pred_df.merge(
        gt_df,
        left_on=["id", "class"],
        right_on=["id", "discourse_type"],
        how="outer",
        suffixes=("_pred", "_gt"),
    )
    joined["predictionstring_gt"] = joined["predictionstring_gt"].fillna(" ")
    joined["predictionstring_pred"] = joined["predictionstring_pred"].fillna(" ")

    joined["overlaps"] = joined.apply(calc_overlap, axis=1)

    # 2. If the overlap between the ground truth and prediction is >= 0.5,
    # and the overlap between the prediction and the ground truth >= 0.5,
    # the prediction is a match and considered a true positive.
    # If multiple matches exist, the match with the highest pair of overlaps is taken.
    joined["overlap1"] = joined["overlaps"].apply(lambda x: eval(str(x))[0])
    joined["overlap2"] = joined["overlaps"].apply(lambda x: eval(str(x))[1])

    joined["potential_TP"] = (joined["overlap1"] >= 0.5) & (joined["overlap2"] >= 0.5)
    joined["max_overlap"] = joined[["overlap1", "overlap2"]].max(axis=1)
    tp_pred_ids = (
        joined.query("potential_TP")
        .sort_values("max_overlap", ascending=False)
        .groupby(["id", "predictionstring_gt"])
        .first()["pred_id"]
        .values
    )

    # 3. Any unmatched ground truths are false negatives
    # and any unmatched predictions are false positives.
    fp_pred_ids = [p for p in joined["pred_id"].unique() if p not in tp_pred_ids]

    matched_gt_ids = joined.query("potential_TP")["gt_id"].unique()
    unmatched_gt_ids = [c for c in joined["gt_id"].unique() if c not in matched_gt_ids]

    # Get numbers of each type
    TP = len(tp_pred_ids)
    FP = len(fp_pred_ids)
    FN = len(unmatched_gt_ids)
    # calc microf1
    my_f1_score = TP / (TP + 0.5 * (FP + FN))
    return my_f1_score


def score_feedback_comp(pred_df, gt_df, return_class_scores=False):
    class_scores = {}
    pred_df = pred_df[["id", "class", "predictionstring"]].reset_index(drop=True).copy()
    for discourse_type, gt_subset in gt_df.groupby("discourse_type"):
        pred_subset = pred_df.loc[pred_df["class"] == discourse_type].reset_index(drop=True).copy()
        class_score = score_feedback_comp_micro(pred_subset, gt_subset)
        class_scores[discourse_type] = class_score
    f1 = np.mean([v for v in class_scores.values()])
    if return_class_scores:
        return f1, class_scores
    return f1


class FeedbackDatasetValid:
    def __init__(self, samples, max_len, tokenizer):
        self.samples = samples
        self.max_len = max_len
        self.tokenizer = tokenizer
        self.length = len(samples)

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        input_ids = self.samples[idx]["input_ids"]
        input_ids = [self.tokenizer.cls_token_id] + input_ids

        if len(input_ids) > self.max_len - 1:
            input_ids = input_ids[: self.max_len - 1]

        # add end token id to the input_ids
        input_ids = input_ids + [self.tokenizer.sep_token_id]
        attention_mask = [1] * len(input_ids)

        return {
            "ids": input_ids,
            "mask": attention_mask,
        }


class Collate:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer

    def __call__(self, batch):
        output = dict()
        output["ids"] = [sample["ids"] for sample in batch]
        output["mask"] = [sample["mask"] for sample in batch]

        # calculate max token length of this batch
        batch_max = max([len(ids) for ids in output["ids"]])

        # add padding
        if self.tokenizer.padding_side == "right":
            output["ids"] = [s + (batch_max - len(s)) * [self.tokenizer.pad_token_id] for s in output["ids"]]
            output["mask"] = [s + (batch_max - len(s)) * [0] for s in output["mask"]]
        else:
            output["ids"] = [(batch_max - len(s)) * [self.tokenizer.pad_token_id] + s for s in output["ids"]]
            output["mask"] = [(batch_max - len(s)) * [0] + s for s in output["mask"]]

        # convert to tensors
        output["ids"] = torch.tensor(output["ids"], dtype=torch.long)
        output["mask"] = torch.tensor(output["mask"], dtype=torch.long)

        return output


class EarlyStopping(Callback):
    def __init__(
        self,
        model_path,
        valid_df,
        valid_samples,
        batch_size,
        tokenizer,
        patience=5,
        mode="max",
        delta=0.001,
        save_weights_only=True,
    ):
        self.patience = patience
        self.counter = 0
        self.mode = mode
        self.best_score = None
        self.early_stop = False
        self.delta = delta
        self.save_weights_only = save_weights_only
        self.model_path = model_path
        self.valid_samples = valid_samples
        self.batch_size = batch_size
        self.valid_df = valid_df
        self.tokenizer = tokenizer

        if self.mode == "min":
            self.val_score = np.Inf
        else:
            self.val_score = -np.Inf

    def on_epoch_end(self, model):
        model.eval()
        valid_dataset = FeedbackDatasetValid(self.valid_samples, 4096, self.tokenizer)
        collate = Collate(self.tokenizer)

        preds_iter = model.predict(
            valid_dataset,
            batch_size=self.batch_size,
            n_jobs=-1,
            collate_fn=collate,
        )

        final_preds = []
        final_scores = []
        for preds in preds_iter:
            pred_class = np.argmax(preds, axis=2)
            pred_scrs = np.max(preds, axis=2)
            for pred, pred_scr in zip(pred_class, pred_scrs):
                final_preds.append(pred.tolist())
                final_scores.append(pred_scr.tolist())

        for j in range(len(self.valid_samples)):
            tt = [id_target_map[p] for p in final_preds[j][1:]]
            tt_score = final_scores[j][1:]
            self.valid_samples[j]["preds"] = tt
            self.valid_samples[j]["pred_scores"] = tt_score

        submission = []
        min_thresh = {
            "Lead": 9,
            "Position": 5,
            "Evidence": 14,
            "Claim": 3,
            "Concluding Statement": 11,
            "Counterclaim": 6,
            "Rebuttal": 4,
        }
        proba_thresh = {
            "Lead": 0.7,
            "Position": 0.55,
            "Evidence": 0.65,
            "Claim": 0.55,
            "Concluding Statement": 0.7,
            "Counterclaim": 0.5,
            "Rebuttal": 0.55,
        }

        for _, sample in enumerate(self.valid_samples):
            preds = sample["preds"]
            offset_mapping = sample["offset_mapping"]
            sample_id = sample["id"]
            sample_text = sample["text"]
            sample_pred_scores = sample["pred_scores"]

            # pad preds to same length as offset_mapping
            if len(preds) < len(offset_mapping):
                preds = preds + ["O"] * (len(offset_mapping) - len(preds))
                sample_pred_scores = sample_pred_scores + [0] * (len(offset_mapping) - len(sample_pred_scores))

            idx = 0
            phrase_preds = []
            while idx < len(offset_mapping):
                start, _ = offset_mapping[idx]
                if preds[idx] != "O":
                    label = preds[idx][2:]
                else:
                    label = "O"
                phrase_scores = []
                phrase_scores.append(sample_pred_scores[idx])
                idx += 1
                while idx < len(offset_mapping):
                    if label == "O":
                        matching_label = "O"
                    else:
                        matching_label = f"I-{label}"
                    if preds[idx] == matching_label:
                        _, end = offset_mapping[idx]
                        phrase_scores.append(sample_pred_scores[idx])
                        idx += 1
                    else:
                        break
                if "end" in locals():
                    phrase = sample_text[start:end]
                    phrase_preds.append((phrase, start, end, label, phrase_scores))

            temp_df = []
            for phrase_idx, (phrase, start, end, label, phrase_scores) in enumerate(phrase_preds):
                word_start = len(sample_text[:start].split())
                word_end = word_start + len(sample_text[start:end].split())
                word_end = min(word_end, len(sample_text.split()))
                ps = " ".join([str(x) for x in range(word_start, word_end)])
                if label != "O":
                    if sum(phrase_scores) / len(phrase_scores) >= proba_thresh[label]:
                        temp_df.append((sample_id, label, ps))

            temp_df = pd.DataFrame(temp_df, columns=["id", "class", "predictionstring"])

            submission.append(temp_df)

        submission = pd.concat(submission).reset_index(drop=True)
        submission["len"] = submission.predictionstring.apply(lambda x: len(x.split()))

        def threshold(df):
            df = df.copy()
            for key, value in min_thresh.items():
                index = df.loc[df["class"] == key].query(f"len<{value}").index
                df.drop(index, inplace=True)
            return df

        submission = threshold(submission)

        # drop len
        submission = submission.drop(columns=["len"])

        scr = score_feedback_comp(submission, self.valid_df, return_class_scores=True)
        print(scr)
        model.train()

        epoch_score = scr[0]
        if self.mode == "min":
            score = -1.0 * epoch_score
        else:
            score = np.copy(epoch_score)

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(epoch_score, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print("EarlyStopping counter: {} out of {}".format(self.counter, self.patience))
            if self.counter >= self.patience:
                model.model_state = enums.ModelState.END
        else:
            self.best_score = score
            self.save_checkpoint(epoch_score, model)
            self.counter = 0

    def save_checkpoint(self, epoch_score, model):
        if epoch_score not in [-np.inf, np.inf, -np.nan, np.nan]:
            print("Validation score improved ({} --> {}). Saving model!".format(self.val_score, epoch_score))
            model.save(self.model_path, weights_only=self.save_weights_only)
        self.val_score = epoch_score

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 7.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 56.4 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.1 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 49.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 58.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.10.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.4 transformers-4.16.2

# %%
import argparse
import os
import random
import warnings

import numpy as np
import pandas as pd
import tez
import torch
import torch.nn as nn
from sklearn import metrics
from torch.nn import functional as F
from transformers import AdamW, AutoConfig, AutoModel, AutoTokenizer, get_cosine_schedule_with_warmup

warnings.filterwarnings("ignore")


def seed_everything(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True


def parse_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--fold", type=int, required=True)
    parser.add_argument("--model", type=str, required=True)
    parser.add_argument("--lr", type=float, required=True)
    parser.add_argument("--output", type=str, default="../model", required=False)
    parser.add_argument("--input", type=str, default="../input", required=False)
    parser.add_argument("--max_len", type=int, default=1024, required=False)
    parser.add_argument("--batch_size", type=int, default=8, required=False)
    parser.add_argument("--valid_batch_size", type=int, default=8, required=False)
    parser.add_argument("--epochs", type=int, default=20, required=False)
    parser.add_argument("--accumulation_steps", type=int, default=1, required=False)
    return parser.parse_args()


class FeedbackDataset:
    def __init__(self, samples, max_len, tokenizer):
        self.samples = samples
        self.max_len = max_len
        self.tokenizer = tokenizer
        self.length = len(samples)

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        input_ids = self.samples[idx]["input_ids"]
        input_labels = self.samples[idx]["input_labels"]
        input_labels = [target_id_map[x] for x in input_labels]
        other_label_id = target_id_map["O"]
        padding_label_id = target_id_map["PAD"]
        # print(input_ids)
        # print(input_labels)

        # add start token id to the input_ids
        input_ids = [self.tokenizer.cls_token_id] + input_ids
        input_labels = [other_label_id] + input_labels

        if len(input_ids) > self.max_len - 1:
            input_ids = input_ids[: self.max_len - 1]
            input_labels = input_labels[: self.max_len - 1]

        # add end token id to the input_ids
        input_ids = input_ids + [self.tokenizer.sep_token_id]
        input_labels = input_labels + [other_label_id]

        attention_mask = [1] * len(input_ids)

        padding_length = self.max_len - len(input_ids)
        if padding_length > 0:
            if self.tokenizer.padding_side == "right":
                input_ids = input_ids + [self.tokenizer.pad_token_id] * padding_length
                input_labels = input_labels + [padding_label_id] * padding_length
                attention_mask = attention_mask + [0] * padding_length
            else:
                input_ids = [self.tokenizer.pad_token_id] * padding_length + input_ids
                input_labels = [padding_label_id] * padding_length + input_labels
                attention_mask = [0] * padding_length + attention_mask

        return {
            "ids": torch.tensor(input_ids, dtype=torch.long),
            "mask": torch.tensor(attention_mask, dtype=torch.long),
            "targets": torch.tensor(input_labels, dtype=torch.long),
        }


class FeedbackModel(tez.Model):
    def __init__(self, model_name, num_train_steps, learning_rate, num_labels, steps_per_epoch):
        super().__init__()
        self.learning_rate = learning_rate
        self.model_name = model_name
        self.num_train_steps = num_train_steps
        self.num_labels = num_labels
        self.steps_per_epoch = steps_per_epoch
        self.step_scheduler_after = "batch"

        hidden_dropout_prob: float = 0.1
        layer_norm_eps: float = 1e-7

        config = AutoConfig.from_pretrained(model_name)

        config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout_prob": hidden_dropout_prob,
                "layer_norm_eps": layer_norm_eps,
                "add_pooling_layer": False,
                "num_labels": self.num_labels,
            }
        )
        self.transformer = AutoModel.from_pretrained(model_name, config=config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.2)
        self.dropout3 = nn.Dropout(0.3)
        self.dropout4 = nn.Dropout(0.4)
        self.dropout5 = nn.Dropout(0.5)
        self.output = nn.Linear(config.hidden_size, self.num_labels)

    def fetch_optimizer(self):
        param_optimizer = list(self.named_parameters())
        no_decay = ["bias", "LayerNorm.bias"]
        optimizer_parameters = [
            {
                "params": [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
                "weight_decay": 0.01,
            },
            {
                "params": [p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
            },
        ]
        opt = AdamW(optimizer_parameters, lr=self.learning_rate)
        return opt

    def fetch_scheduler(self):
        sch = get_cosine_schedule_with_warmup(
            self.optimizer,
            num_warmup_steps=int(0.1 * self.num_train_steps),
            num_training_steps=self.num_train_steps,
            num_cycles=1,
            last_epoch=-1,
        )
        return sch

    def loss(self, outputs, targets, attention_mask):
        loss_fct = nn.CrossEntropyLoss()

        active_loss = attention_mask.view(-1) == 1
        active_logits = outputs.view(-1, self.num_labels)
        true_labels = targets.view(-1)
        outputs = active_logits.argmax(dim=-1)
        idxs = np.where(active_loss.cpu().numpy() == 1)[0]
        active_logits = active_logits[idxs]
        true_labels = true_labels[idxs].to(torch.long)

        loss = loss_fct(active_logits, true_labels)
        return loss

    def monitor_metrics(self, outputs, targets, attention_mask):
        active_loss = (attention_mask.view(-1) == 1).cpu().numpy()
        active_logits = outputs.view(-1, self.num_labels)
        true_labels = targets.view(-1).cpu().numpy()
        outputs = active_logits.argmax(dim=-1).cpu().numpy()
        idxs = np.where(active_loss == 1)[0]
        f1_score = metrics.f1_score(true_labels[idxs], outputs[idxs], average="macro")
        return {"f1": f1_score}

    def forward(self, ids, mask, token_type_ids=None, targets=None):

        if token_type_ids:
            transformer_out = self.transformer(ids, mask, token_type_ids)
        else:
            transformer_out = self.transformer(ids, mask)
        sequence_output = transformer_out.last_hidden_state
        sequence_output = self.dropout(sequence_output)

        logits1 = self.output(self.dropout1(sequence_output))
        logits2 = self.output(self.dropout2(sequence_output))
        logits3 = self.output(self.dropout3(sequence_output))
        logits4 = self.output(self.dropout4(sequence_output))
        logits5 = self.output(self.dropout5(sequence_output))

        logits = (logits1 + logits2 + logits3 + logits4 + logits5) / 5
        logits = torch.softmax(logits, dim=-1)
        loss = 0

        if targets is not None:
            loss1 = self.loss(logits1, targets, attention_mask=mask)
            loss2 = self.loss(logits2, targets, attention_mask=mask)
            loss3 = self.loss(logits3, targets, attention_mask=mask)
            loss4 = self.loss(logits4, targets, attention_mask=mask)
            loss5 = self.loss(logits5, targets, attention_mask=mask)
            loss = (loss1 + loss2 + loss3 + loss4 + loss5) / 5
            f1_1 = self.monitor_metrics(logits1, targets, attention_mask=mask)["f1"]
            f1_2 = self.monitor_metrics(logits2, targets, attention_mask=mask)["f1"]
            f1_3 = self.monitor_metrics(logits3, targets, attention_mask=mask)["f1"]
            f1_4 = self.monitor_metrics(logits4, targets, attention_mask=mask)["f1"]
            f1_5 = self.monitor_metrics(logits5, targets, attention_mask=mask)["f1"]
            f1 = (f1_1 + f1_2 + f1_3 + f1_4 + f1_5) / 5
            metric = {"f1": f1}
            return logits, loss, metric

        return logits, loss, {}

# %%
os.mkdir('new-dir')
# !unzip '/content/drive/MyDrive/Super Resolution/results.zip' -d 'new-dir'
# Out:
# Archive:  /content/drive/MyDrive/Super Resolution/results.zip
#   inflating: new-dir/train_folds.csv

# %%
NUM_JOBS = 12
# args = parse_args()
seed_everything(42)
os.makedirs(args.output, exist_ok=True)
df = pd.read_csv("/content/new-dir/train_folds.csv")

# %%
train_df = df[df["kfold"] != args.fold].reset_index(drop=True)
valid_df = df[df["kfold"] == args.fold].reset_index(drop=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(args.model)
training_samples = prepare_training_data(train_df, tokenizer, args, num_jobs=NUM_JOBS)
valid_samples = prepare_training_data(valid_df, tokenizer, args, num_jobs=NUM_JOBS)

train_dataset = FeedbackDataset(training_samples, args.max_len, tokenizer)

num_train_steps = int(len(train_dataset) / args.batch_size / args.accumulation_steps * args.epochs)
print(num_train_steps)
# Out:
# Downloading:   0%|          | 0.00/866 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
#  13%|█▎        | 139/1039 [00:37<03:02,  4.92it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (6223 > 4096). Running this sequence through the model will result in indexing errors
#  38%|███▊      | 395/1040 [01:14<01:47,  6.01it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (7581 > 4096). Running this sequence through the model will result in indexing errors
#  40%|███▉      | 411/1040 [01:29<02:11,  4.77it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (8566 > 4096). Running this sequence through the model will result in indexing errors
#  39%|███▉      | 410/1039 [01:22<01:28,  7.07it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (8844 > 4096). Running this sequence through the model will result in indexing errors
#  62%|██████▏   | 649/1040 [02:18<01:11,  5.44it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (14761 > 4096). Running this sequence through the model will result in indexing errors
# 100%|██████████| 1040/1040 [03:20<00:00,  5.20it/s]
# 100%|██████████| 1040/1040 [03:28<00:00,  5.00it/s]
# 100%|██████████| 1040/1040 [03:22<00:00,  5.12it/s]
# 100%|██████████| 1040/1040 [03:28<00:00,  5.00it/s]
# 100%|██████████| 1040/1040 [03:28<00:00,  4.99it/s]
# 100%|██████████| 1040/1040 [03:32<00:00,  4.88it/s]
# 100%|██████████| 1039/1039 [03:24<00:00,  5.08it/s]
# 100%|██████████| 1040/1040 [03:38<00:00,  4.76it/s]
# 100%|██████████| 1040/1040 [03:31<00:00,  4.91it/s]
# 100%|██████████| 1039/1039 [03:24<00:00,  5.09it/s]
# 100%|██████████| 1040/1040 [03:30<00:00,  4.94it/s]
# 100%|██████████| 1039/1039 [03:27<00:00,  5.00it/s]
# 100%|██████████| 260/260 [00:25<00:00, 10.29it/s]
# 100%|██████████| 260/260 [00:26<00:00,  9.73it/s]
#  62%|██████▏   | 161/260 [00:25<00:16,  6.01it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (4104 > 4096). Running this sequence through the model will result in indexing errors
# 100%|██████████| 260/260 [00:29<00:00,  8.70it/s]
# 100%|██████████| 260/260 [00:30<00:00,  8.46it/s]
# 100%|██████████| 260/260 [00:30<00:00,  8.50it/s]
# 100%|██████████| 260/260 [00:29<00:00,  8.95it/s]
# 100%|██████████| 260/260 [00:33<00:00,  7.83it/s]
# 100%|██████████| 260/260 [00:31<00:00,  8.38it/s]
# 100%|██████████| 260/260 [00:32<00:00,  7.92it/s]
# 100%|██████████| 259/259 [00:31<00:00,  8.31it/s]
# 100%|██████████| 259/259 [00:30<00:00,  8.58it/s]
# 100%|██████████| 259/259 [00:30<00:00,  8.46it/s]
# 62385

# %%
model = FeedbackModel(
    model_name=args.model,
    num_train_steps=num_train_steps,
    learning_rate=args.lr,
    num_labels=len(target_id_map) - 1,
    steps_per_epoch=len(train_dataset) / args.batch_size,
)

es = EarlyStopping(
    model_path=os.path.join(args.output, f"model_{args.fold}.bin"),
    valid_df=valid_df,
    valid_samples=valid_samples,
    batch_size=args.valid_batch_size,
    patience=5,
    mode="max",
    delta=0.001,
    save_weights_only=True,
    tokenizer=tokenizer,
)
# Out:
# Downloading:   0%|          | 0.00/1.62G [00:00<?, ?B/s]
# Some weights of the model checkpoint at allenai/longformer-large-4096-finetuned-triviaqa were not used when initializing LongformerModel: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing LongformerModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.fit(
    train_dataset,
    train_bs=args.batch_size,
    device="cuda",
    epochs=args.epochs,
    callbacks=[es],
    fp16=True,
    accumulation_steps=args.accumulation_steps,
)
# Out:
# 100%|██████████| 12477/12477 [4:41:16<00:00,  1.35s/it, f1=0.477, loss=0.843, stage=train]
# 100%|██████████| 1559/1559 [08:44<00:00,  2.97it/s, stage=test]
# (0.576268567027996, {'Claim': 0.5969521807672097, 'Concluding Statement': 0.49109279446955595, 'Counterclaim': 0.4273756770064008, 'Evidence': 0.7175449686799609, 'Lead': 0.7633628793983347, 'Position': 0.6777188328912467, 'Rebuttal': 0.3598326359832636})
# Validation score improved (-inf --> 0.576268567027996). Saving model!
# 100%|██████████| 12477/12477 [4:41:09<00:00,  1.35s/it, f1=0.629, loss=0.568, stage=train]
# 100%|██████████| 1559/1559 [08:44<00:00,  2.97it/s, stage=test]
# (0.6567038161320733, {'Claim': 0.6416112956810631, 'Concluding Statement': 0.8039950062421972, 'Counterclaim': 0.5006681514476615, 'Evidence': 0.7380582092868252, 'Lead': 0.8105631905146861, 'Position': 0.6947581324793528, 'Rebuttal': 0.4072727272727273})
# Validation score improved (0.576268567027996 --> 0.6567038161320733). Saving model!
# 100%|██████████| 12477/12477 [4:41:09<00:00,  1.35s/it, f1=0.69, loss=0.433, stage=train]
# 100%|██████████| 1559/1559 [08:43<00:00,  2.98it/s, stage=test]
# (0.6594095022688362, {'Claim': 0.6442888959592746, 'Concluding Statement': 0.8164807484706729, 'Counterclaim': 0.509212730318258, 'Evidence': 0.7355194268393497, 'Lead': 0.803788903924222, 'Position': 0.6962913464751086, 'Rebuttal': 0.4102844638949672})
# Validation score improved (0.6567038161320733 --> 0.6594095022688362). Saving model!
#  48%|████▊     | 6051/12477 [2:16:28<2:24:55,  1.35s/it, f1=0.698, loss=0.416, stage=train]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0b475979a0e0> in <module>()
#       6     callbacks=[es],
#       7     fp16=True,
# ----> 8     accumulation_steps=args.accumulation_steps,
#       9 )
#
# /usr/local/lib/python3.7/dist-packages/tez/model/model.py in fit(self, train_dataset, valid_dataset, train_sampler, valid_sampler, device, epochs, train_bs, valid_bs, n_jobs, callbacks, fp16, train_collate_fn, valid_collate_fn, train_shuffle, valid_shuffle, accumulation_steps, clip_grad_norm)
#     408             self.train_state = enums.TrainingState.EPOCH_START
#     409             self.train_state = enums.TrainingState.TRAIN_EPOCH_START
# --> 410             train_loss = self.train_one_epoch(self.train_loader)
#     411             self.train_state = enums.TrainingState.TRAIN_EPOCH_END
#     412             if self.valid_loader:
#
# /usr/local/lib/python3.7/dist-packages/tez/model/model.py in train_one_epoch(self, data_loader)
#     226             self.batch_index = b_idx
#     227             self.train_state = enums.TrainingState.TRAIN_STEP_START
# --> 228             loss, metrics = self.train_one_step(data)
#     229             self.train_state = enums.TrainingState.TRAIN_STEP_END
#     230             losses.update(loss.item() * self.accumulation_steps, data_loader.batch_size)
#
# /usr/local/lib/python3.7/dist-packages/tez/model/model.py in train_one_step(self, data)
#     176         loss = loss / self.accumulation_steps
#     177         if self.fp16:
# --> 178             self.scaler.scale(loss).backward()
#     179         else:
#     180             loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
# !cp /content/model_3.bin '/content/drive/MyDrive/Super Resolution'

# %%
# !cp /content/model_1.bin '/content/drive/MyDrive/Super Resolution'
